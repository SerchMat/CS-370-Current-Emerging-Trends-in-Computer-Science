# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
from scores.score_logger import ScoreLogger

  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.8433051360508336, score: 54
# Scores: (min: 54, avg: 54, max: 54)
#
# Run: 2, exploration: 0.7590483508202912, score: 22
# Scores: (min: 22, avg: 38, max: 54)
#
# Run: 3, exploration: 0.6763948591909945, score: 24
# Scores: (min: 22, avg: 33.333333333333336, max: 54)
#
# Run: 4, exploration: 0.6149486215357263, score: 20
# Scores: (min: 20, avg: 30, max: 54)
#
# Run: 5, exploration: 0.5535075230322891, score: 22
# Scores: (min: 20, avg: 28.4, max: 54)
#
# Run: 6, exploration: 0.5159963842937159, score: 15
# Scores: (min: 15, avg: 26.166666666666668, max: 54)
#
# Run: 7, exploration: 0.4907693883854626, score: 11
# Scores: (min: 11, avg: 24, max: 54)
#
# Run: 8, exploration: 0.46912134373457726, score: 10
# Scores: (min: 10, avg: 22.25, max: 54)
#
# Run: 9, exploration: 0.4417353564707963, score: 13
# Scores: (min: 10, avg: 21.22222222222222, max: 54)
#
# Run: 10, exploration: 0.4222502236424958, score: 10
# Scores: (min: 10, avg: 20.1, max: 54)
#
# Run: 11, exploration: 0.4036245882390106, score: 10
# Scores: (min: 10, avg: 19.181818181818183, max: 54)
#
# Run: 12, exploration: 0.3858205374665315, score: 10
# Scores: (min: 10, avg: 18.416666666666668, max: 54)
#
# Run: 13, exploration: 0.36880183088056995, score: 10
# Scores: (min: 10, avg: 17.76923076923077, max: 54)
#
# Run: 14, exploration: 0.35253382661792404, score: 10
# Scores: (min: 10, avg: 17.214285714285715, max: 54)
#
# Run: 15, exploration: 0.3157247089126454, score: 23
# Scores: (min: 10, avg: 17.6, max: 54)
#
# Run: 16, exploration: 0.3033145315372582, score: 9
# Scores: (min: 9, avg: 17.0625, max: 54)
#
# Run: 17, exploration: 0.28704309604425327, score: 12
# Scores: (min: 9, avg: 16.764705882352942, max: 54)
#
# Run: 18, exploration: 0.27164454854530906, score: 12
# Scores: (min: 9, avg: 16.5, max: 54)
#
# Run: 19, exploration: 0.2609670281126685, score: 9
# Scores: (min: 9, avg: 16.105263157894736, max: 54)
#
# Run: 20, exploration: 0.2494556624678441, score: 10
# Scores: (min: 9, avg: 15.8, max: 54)
#
# Run: 21, exploration: 0.2408545925762412, score: 8
# Scores: (min: 8, avg: 15.428571428571429, max: 54)
#
# Run: 22, exploration: 0.22679417751985861, score: 13
# Scores: (min: 8, avg: 15.318181818181818, max: 54)
#
# Run: 23, exploration: 0.2167901907234072, score: 10
# Scores: (min: 8, avg: 15.08695652173913, max: 54)
#
# Run: 24, exploration: 0.20619134658263935, score: 11
# Scores: (min: 8, avg: 14.916666666666666, max: 54)
#
# Run: 25, exploration: 0.19709615934585656, score: 10
# Scores: (min: 8, avg: 14.72, max: 54)
#
# Run: 26, exploration: 0.18840216465300522, score: 10
# Scores: (min: 8, avg: 14.538461538461538, max: 54)
#
# Run: 27, exploration: 0.17829525136613786, score: 12
# Scores: (min: 8, avg: 14.444444444444445, max: 54)
#
# Run: 28, exploration: 0.17043057265153258, score: 10
# Scores: (min: 8, avg: 14.285714285714286, max: 54)
#
# Run: 29, exploration: 0.16455423674261854, score: 8
# Scores: (min: 8, avg: 14.068965517241379, max: 54)
#
# Run: 30, exploration: 0.15650920157696743, score: 11
# Scores: (min: 8, avg: 13.966666666666667, max: 54)
#
# Run: 31, exploration: 0.14960551470448571, score: 10
# Scores: (min: 8, avg: 13.838709677419354, max: 54)
#
# Run: 32, exploration: 0.14372497725712216, score: 9
# Scores: (min: 8, avg: 13.6875, max: 54)
#
# Run: 33, exploration: 0.1346580429260134, score: 14
# Scores: (min: 8, avg: 13.696969696969697, max: 54)
#
# Run: 34, exploration: 0.12871821987500112, score: 10
# Scores: (min: 8, avg: 13.588235294117647, max: 54)
#
# Run: 35, exploration: 0.12242520289863423, score: 11
# Scores: (min: 8, avg: 13.514285714285714, max: 54)
#
# Run: 36, exploration: 0.1176130407830293, score: 9
# Scores: (min: 8, avg: 13.38888888888889, max: 54)
#
# Run: 37, exploration: 0.11299003011401039, score: 9
# Scores: (min: 8, avg: 13.27027027027027, max: 54)
#
# Run: 38, exploration: 0.10800599224428936, score: 10
# Scores: (min: 8, avg: 13.18421052631579, max: 54)
#
# Run: 39, exploration: 0.10272559337455119, score: 11
# Scores: (min: 8, avg: 13.128205128205128, max: 54)
#
# Run: 40, exploration: 0.09819432413732986, score: 10
# Scores: (min: 8, avg: 13.05, max: 54)
#
# Run: 41, exploration: 0.09339361644125409, score: 11
# Scores: (min: 8, avg: 13, max: 54)
#
# Run: 42, exploration: 0.08972259762946533, score: 9
# Scores: (min: 8, avg: 12.904761904761905, max: 54)
#
# Run: 43, exploration: 0.08662902049662846, score: 8
# Scores: (min: 8, avg: 12.790697674418604, max: 54)
#
# Run: 44, exploration: 0.0832238973628649, score: 9
# Scores: (min: 8, avg: 12.704545454545455, max: 54)
#
# Run: 45, exploration: 0.07955285615946175, score: 10
# Scores: (min: 8, avg: 12.644444444444444, max: 54)
#
# Run: 46, exploration: 0.07680992513462537, score: 8
# Scores: (min: 8, avg: 12.543478260869565, max: 54)
#
# Run: 47, exploration: 0.07232597730414898, score: 13
# Scores: (min: 8, avg: 12.553191489361701, max: 54)
#
# Run: 48, exploration: 0.0660860453679829, score: 19
# Scores: (min: 8, avg: 12.6875, max: 54)
#
# Run: 49, exploration: 0.06191698689958447, score: 14
# Scores: (min: 8, avg: 12.714285714285714, max: 54)
#
# Run: 50, exploration: 0.04867631463831842, score: 49
# Scores: (min: 8, avg: 13.44, max: 54)
#
# Run: 51, exploration: 0.03694767635022522, score: 56
# Scores: (min: 8, avg: 14.27450980392157, max: 56)
#
# Run: 52, exploration: 0.032109488810599975, score: 29
# Scores: (min: 8, avg: 14.557692307692308, max: 56)
#
# Run: 53, exploration: 0.029933432588273214, score: 15
# Scores: (min: 8, avg: 14.566037735849056, max: 56)
#
# Run: 54, exploration: 0.024991218342344988, score: 37
# Scores: (min: 8, avg: 14.981481481481481, max: 56)
#
# Run: 55, exploration: 0.022949847368015076, score: 18
# Scores: (min: 8, avg: 15.036363636363637, max: 56)
#
# Run: 56, exploration: 0.015138941243677408, score: 84
# Scores: (min: 8, avg: 16.267857142857142, max: 84)
#
# Run: 57, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 17.473684210526315, max: 85)
#
# Run: 58, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 18.32758620689655, max: 85)
#
# Run: 59, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 18.74576271186441, max: 85)
#
# Run: 60, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 19.933333333333334, max: 90)
#
# Run: 61, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 20.24590163934426, max: 90)
#
# Run: 62, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 20.677419354838708, max: 90)
#
# Run: 63, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 23.428571428571427, max: 194)
#
# Run: 64, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 23.921875, max: 194)
#
# Run: 65, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 24.56923076923077, max: 194)
#
# Run: 66, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 25.303030303030305, max: 194)
#
# Run: 67, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 25.328358208955223, max: 194)
#
# Run: 68, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 25.41176470588235, max: 194)
#
# Run: 69, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 25.608695652173914, max: 194)
#
# Run: 70, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 26.17142857142857, max: 194)
#
# Run: 71, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 27.985915492957748, max: 194)
#
# Run: 72, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 29.13888888888889, max: 194)
#
# Run: 73, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 31.246575342465754, max: 194)
#
# Run: 74, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 33.932432432432435, max: 230)
#
# Run: 75, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 36.64, max: 237)
#
# Run: 76, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 38.10526315789474, max: 237)
#
# Run: 77, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 39.54545454545455, max: 237)
#
# Run: 78, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 45.44871794871795, max: 500)
#
# Run: 79, exploration: 0.01, score: 246
# Scores: (min: 8, avg: 47.9873417721519, max: 500)
#
# Run: 80, exploration: 0.01, score: 351
# Scores: (min: 8, avg: 51.775, max: 500)
#
# Run: 81, exploration: 0.01, score: 298
# Scores: (min: 8, avg: 54.81481481481482, max: 500)
#
# Run: 82, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 57.69512195121951, max: 500)
#
# Run: 83, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 58.53012048192771, max: 500)
#
# Run: 84, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 60.30952380952381, max: 500)
#
# Run: 85, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 62.43529411764706, max: 500)
# Run: 86, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 63.45348837209303, max: 500)
#
# Run: 87, exploration: 0.01, score: 396
# Scores: (min: 8, avg: 67.27586206896552, max: 500)
#
# Run: 88, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 69.81818181818181, max: 500)
#
# Run: 89, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 71.74157303370787, max: 500)
#
# Run: 90, exploration: 0.01, score: 460
# Scores: (min: 8, avg: 76.05555555555556, max: 500)
#
# Run: 91, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 78.62637362637362, max: 500)
#
# Run: 92, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 80.34782608695652, max: 500)
#
# Run: 93, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 81.83870967741936, max: 500)
#
# Run: 94, exploration: 0.01, score: 301
# Scores: (min: 8, avg: 84.17021276595744, max: 500)
#
# Run: 95, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 85.71578947368421, max: 500)
#
# Run: 96, exploration: 0.01, score: 252
# Scores: (min: 8, avg: 87.44791666666667, max: 500)
#
# Run: 97, exploration: 0.01, score: 377
# Scores: (min: 8, avg: 90.43298969072166, max: 500)
#
# Run: 98, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 91.77551020408163, max: 500)
#
# Run: 99, exploration: 0.01, score: 290
# Scores: (min: 8, avg: 93.77777777777777, max: 500)
#
# Run: 100, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 95.11, max: 500)
#
# Run: 101, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 96.65, max: 500)
#
# Run: 102, exploration: 0.01, score: 267
# Scores: (min: 8, avg: 99.1, max: 500)
#
# Run: 103, exploration: 0.01, score: 393
# Scores: (min: 8, avg: 102.79, max: 500)
#
# Run: 104, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 104.64, max: 500)
#
# Run: 105, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 106.79, max: 500)
#
# Run: 106, exploration: 0.01, score: 414
# Scores: (min: 8, avg: 110.78, max: 500)
#
# Run: 107, exploration: 0.01, score: 414
# Scores: (min: 8, avg: 114.81, max: 500)
#
# Run: 108, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 116.58, max: 500)
#
# Run: 109, exploration: 0.01, score: 327
# Scores: (min: 8, avg: 119.72, max: 500)
#
# Run: 110, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 121.46, max: 500)
#
# Run: 111, exploration: 0.01, score: 277
# Scores: (min: 8, avg: 124.13, max: 500)
#
# Run: 112, exploration: 0.01, score: 380
# Scores: (min: 8, avg: 127.83, max: 500)
#
# Run: 113, exploration: 0.01, score: 398
# Scores: (min: 8, avg: 131.71, max: 500)
#
# Run: 114, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 133.62, max: 500)
#
# Run: 115, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 135.68, max: 500)
#
# Run: 116, exploration: 0.01, score: 332
# Scores: (min: 8, avg: 138.91, max: 500)
#
# Run: 117, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 141.42, max: 500)
#
# Run: 118, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 143.07, max: 500)
#
# Run: 119, exploration: 0.01, score: 273
# Scores: (min: 8, avg: 145.71, max: 500)
#
# Run: 120, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 147.46, max: 500)
#
# Run: 121, exploration: 0.01, score: 462
# Scores: (min: 8, avg: 152, max: 500)
#
# Run: 122, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 153.62, max: 500)
#
# Run: 123, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 155.67, max: 500)
#
# Run: 124, exploration: 0.01, score: 252
# Scores: (min: 8, avg: 158.08, max: 500)
#
# Run: 125, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 160.19, max: 500)
#
# Run: 126, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 161.64, max: 500)
#
# Run: 127, exploration: 0.01, score: 285
# Scores: (min: 8, avg: 164.37, max: 500)
#
# Run: 128, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 165.93, max: 500)
#
# Run: 129, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 168.22, max: 500)
#
# Run: 130, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 170.34, max: 500)
#
# Run: 131, exploration: 0.01, score: 247
# Scores: (min: 8, avg: 172.71, max: 500)
#
# Run: 132, exploration: 0.01, score: 265
# Scores: (min: 8, avg: 175.27, max: 500)
#
# Run: 133, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 177.13, max: 500)
#
# Run: 134, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 179.4, max: 500)
#
# Run: 135, exploration: 0.01, score: 340
# Scores: (min: 8, avg: 182.69, max: 500)
#
# Run: 136, exploration: 0.01, score: 228
# Scores: (min: 8, avg: 184.88, max: 500)
#
# Run: 137, exploration: 0.01, score: 270
# Scores: (min: 8, avg: 187.49, max: 500)
#
# Run: 138, exploration: 0.01, score: 413
# Scores: (min: 8, avg: 191.52, max: 500)
#
# Run: 139, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 193.73, max: 500)
#
# Run: 140, exploration: 0.01, score: 315
# Scores: (min: 8, avg: 196.78, max: 500)
#
# Solved in 40 runs, 140 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-6-9bf7ec961077> in cartpole()
#      83             if terminal:
#      84                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 85                 score_logger.add_score(step, run)
#      86                 break
#      87             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
from scores.score_logger import ScoreLogger

# Modified cartpole: increased gamma to 0.995

ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.995  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 19
# Scores: (min: 19, avg: 19, max: 19)
#
# Run: 2, exploration: 0.9322301194154049, score: 15
# Scores: (min: 15, avg: 17, max: 19)
#
# Run: 3, exploration: 0.8690529955452602, score: 15
# Scores: (min: 15, avg: 16.333333333333332, max: 19)
#
# Run: 4, exploration: 0.7328768546436799, score: 35
# Scores: (min: 15, avg: 21, max: 35)
#
# Run: 5, exploration: 0.697046600835495, score: 11
# Scores: (min: 11, avg: 19, max: 35)
#
# Run: 6, exploration: 0.6563549768288433, score: 13
# Scores: (min: 11, avg: 18, max: 35)
#
# Run: 7, exploration: 0.6180388156137953, score: 13
# Scores: (min: 11, avg: 17.285714285714285, max: 35)
#
# Run: 8, exploration: 0.5848838636585911, score: 12
# Scores: (min: 11, avg: 16.625, max: 35)
#
# Run: 9, exploration: 0.5159963842937159, score: 26
# Scores: (min: 11, avg: 17.666666666666668, max: 35)
#
# Run: 10, exploration: 0.4932355662165453, score: 10
# Scores: (min: 10, avg: 16.9, max: 35)
#
# Run: 11, exploration: 0.45522245551230495, score: 17
# Scores: (min: 10, avg: 16.90909090909091, max: 35)
#
# Run: 12, exploration: 0.43080185560799106, score: 12
# Scores: (min: 10, avg: 16.5, max: 35)
#
# Run: 13, exploration: 0.41386834584198684, score: 9
# Scores: (min: 9, avg: 15.923076923076923, max: 35)
#
# Run: 14, exploration: 0.3936343764094253, score: 11
# Scores: (min: 9, avg: 15.571428571428571, max: 35)
#
# Run: 15, exploration: 0.36880183088056995, score: 14
# Scores: (min: 9, avg: 15.466666666666667, max: 35)
#
# Run: 16, exploration: 0.34901730169741024, score: 12
# Scores: (min: 9, avg: 15.25, max: 35)
#
# Run: 17, exploration: 0.33195389135223546, score: 11
# Scores: (min: 9, avg: 15, max: 35)
#
# Run: 18, exploration: 0.30945741577570285, score: 15
# Scores: (min: 9, avg: 15, max: 35)
#
# Run: 19, exploration: 0.29580711868545667, score: 10
# Scores: (min: 9, avg: 14.736842105263158, max: 35)
#
# Run: 20, exploration: 0.2827589419554058, score: 10
# Scores: (min: 9, avg: 14.5, max: 35)
#
# Run: 21, exploration: 0.2689348941735696, score: 11
# Scores: (min: 9, avg: 14.333333333333334, max: 35)
#
# Run: 22, exploration: 0.2519690537792925, score: 14
# Scores: (min: 9, avg: 14.318181818181818, max: 35)
#
# Run: 23, exploration: 0.23371867538818816, score: 16
# Scores: (min: 9, avg: 14.391304347826088, max: 35)
#
# Run: 24, exploration: 0.2010878536592394, score: 31
# Scores: (min: 9, avg: 15.083333333333334, max: 35)
#
# Run: 25, exploration: 0.16048131420416054, score: 46
# Scores: (min: 9, avg: 16.32, max: 46)
#
# Run: 26, exploration: 0.1346580429260134, score: 36
# Scores: (min: 9, avg: 17.076923076923077, max: 46)
#
# Run: 27, exploration: 0.0996820918179746, score: 61
# Scores: (min: 9, avg: 18.703703703703702, max: 61)
#
# Run: 28, exploration: 0.0691356479495614, score: 74
# Scores: (min: 9, avg: 20.678571428571427, max: 74)
#
# Run: 29, exploration: 0.044924885780066794, score: 87
# Scores: (min: 9, avg: 22.96551724137931, max: 87)
#
# Run: 30, exploration: 0.018042124582040707, score: 183
# Scores: (min: 9, avg: 28.3, max: 183)
#
# Run: 31, exploration: 0.01166529436067347, score: 88
# Scores: (min: 9, avg: 30.225806451612904, max: 183)
#
# Run: 32, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 32.3125, max: 183)
#
# Run: 33, exploration: 0.01, score: 90
# Scores: (min: 9, avg: 34.06060606060606, max: 183)
#
# Run: 34, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 37.205882352941174, max: 183)
#
# Run: 35, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 38.457142857142856, max: 183)
#
# Run: 36, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 41.30555555555556, max: 183)
#
# Run: 37, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 42.37837837837838, max: 183)
#
# Run: 38, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 48.36842105263158, max: 270)
#
# Run: 39, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 49.256410256410255, max: 270)
#
# Run: 40, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 52.05, max: 270)
#
# Run: 41, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 53.073170731707314, max: 270)
#
# Run: 42, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 54.04761904761905, max: 270)
#
# Run: 43, exploration: 0.01, score: 86
# Scores: (min: 9, avg: 54.7906976744186, max: 270)
#
# Run: 44, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 56.47727272727273, max: 270)
#
# Run: 45, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 59.06666666666667, max: 270)
#
# Run: 46, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 61.08695652173913, max: 270)
#
# Run: 47, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 63.340425531914896, max: 270)
#
# Run: 48, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 65.08333333333333, max: 270)
#
# Run: 49, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 68.51020408163265, max: 270)
#
# Run: 50, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 69.94, max: 270)
#
# Run: 51, exploration: 0.01, score: 325
# Scores: (min: 9, avg: 74.94117647058823, max: 325)
#
# Run: 52, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 83.11538461538461, max: 500)
#
# Run: 53, exploration: 0.01, score: 423
# Scores: (min: 9, avg: 89.52830188679245, max: 500)
#
# Run: 54, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 88.14814814814815, max: 500)
#
# Run: 55, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 86.94545454545455, max: 500)
#
# Run: 56, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 94.32142857142857, max: 500)
#
# Run: 57, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 95.80701754385964, max: 500)
#
# Run: 58, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 102.77586206896552, max: 500)
#
# Run: 59, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 104.71186440677967, max: 500)
#
# Run: 60, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 111.3, max: 500)
#
# Run: 61, exploration: 0.01, score: 260
# Scores: (min: 9, avg: 113.73770491803279, max: 500)
#
# Run: 62, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 119.96774193548387, max: 500)
#
# Run: 63, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 126, max: 500)
#
# Run: 64, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 131.84375, max: 500)
#
# Run: 65, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 137.5076923076923, max: 500)
#
# Run: 66, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 143, max: 500)
#
# Run: 67, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 148.32835820895522, max: 500)
#
# Run: 68, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 153.5, max: 500)
#
# Run: 69, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 158.52173913043478, max: 500)
#
# Run: 70, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 163.4, max: 500)
#
# Run: 71, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 168.14084507042253, max: 500)
#
# Run: 72, exploration: 0.01, score: 202
# Scores: (min: 9, avg: 168.61111111111111, max: 500)
#
# Run: 73, exploration: 0.01, score: 384
# Scores: (min: 9, avg: 171.56164383561645, max: 500)
#
# Run: 74, exploration: 0.01, score: 242
# Scores: (min: 9, avg: 172.51351351351352, max: 500)
#
# Run: 75, exploration: 0.01, score: 312
# Scores: (min: 9, avg: 174.37333333333333, max: 500)
#
# Run: 76, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 178.6578947368421, max: 500)
#
# Run: 77, exploration: 0.01, score: 466
# Scores: (min: 9, avg: 182.3896103896104, max: 500)
#
# Run: 78, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 186.46153846153845, max: 500)
#
# Run: 79, exploration: 0.01, score: 289
# Scores: (min: 9, avg: 187.7594936708861, max: 500)
#
# Run: 80, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 191.6625, max: 500)
#
# Run: 81, exploration: 0.01, score: 395
# Scores: (min: 9, avg: 194.17283950617283, max: 500)
#
# Run: 82, exploration: 0.01, score: 249
# Scores: (min: 9, avg: 194.84146341463415, max: 500)
#
# Run: 83, exploration: 0.01, score: 337
# Scores: (min: 9, avg: 196.55421686746988, max: 500)
#
# Run: 84, exploration: 0.01, score: 477
# Scores: (min: 9, avg: 199.89285714285714, max: 500)
#
# Run: 85, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 199.65882352941176, max: 500)
#
# Run: 86, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 199.67441860465115, max: 500)
#
# Run: 87, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 203.1264367816092, max: 500)
#
# Run: 88, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 202.7840909090909, max: 500)
#
# Run: 89, exploration: 0.01, score: 419
# Scores: (min: 9, avg: 205.2134831460674, max: 500)
# Run: 90, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 203.04444444444445, max: 500)
#
# Run: 91, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 200.92307692307693, max: 500)
#
# Run: 92, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 198.83695652173913, max: 500)
#
# Run: 93, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 196.80645161290323, max: 500)
#
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 194.81914893617022, max: 500)
#
# Run: 95, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 192.86315789473684, max: 500)
#
# Run: 96, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 190.95833333333334, max: 500)
#
# Run: 97, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 189.09278350515464, max: 500)
#
# Run: 98, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 187.26530612244898, max: 500)
#
# Run: 99, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 185.4747474747475, max: 500)
#
# Run: 100, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 183.72, max: 500)
#
# Run: 101, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 183.63, max: 500)
#
# Run: 102, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 183.58, max: 500)
#
# Run: 103, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 183.53, max: 500)
#
# Run: 104, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 183.28, max: 500)
#
# Run: 105, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 183.26, max: 500)
#
# Run: 106, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 183.22, max: 500)
#
# Run: 107, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 183.17, max: 500)
#
# Run: 108, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 183.14, max: 500)
#
# Run: 109, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.97, max: 500)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 182.97, max: 500)
#
# Run: 111, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.89, max: 500)
#
# Run: 112, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 182.85, max: 500)
#
# Run: 113, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 182.86, max: 500)
#
# Run: 114, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 182.85, max: 500)
#
# Run: 115, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.8, max: 500)
#
# Run: 116, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.77, max: 500)
#
# Run: 117, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.75, max: 500)
#
# Run: 118, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 182.68, max: 500)
#
# Run: 119, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 182.68, max: 500)
#
# Run: 120, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.67, max: 500)
#
# Run: 121, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.65, max: 500)
#
# Run: 122, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 182.61, max: 500)
#
# Run: 123, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.54, max: 500)
#
# Run: 124, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.32, max: 500)
#
# Run: 125, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 181.95, max: 500)
#
# Run: 126, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 181.69, max: 500)
#
# Run: 127, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 181.18, max: 500)
#
# Run: 128, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 180.54, max: 500)
#
# Run: 129, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 179.75, max: 500)
#
# Run: 130, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 178, max: 500)
#
# Run: 131, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 177.21, max: 500)
#
# Run: 132, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 176.34, max: 500)
#
# Run: 133, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 175.54, max: 500)
#
# Run: 134, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 174.23, max: 500)
#
# Run: 135, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 173.51, max: 500)
#
# Run: 136, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 172.19, max: 500)
#
# Run: 137, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 171.46, max: 500)
#
# Run: 138, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 168.85, max: 500)
#
# Run: 139, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 168.13, max: 500)
#
# Run: 140, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 166.62, max: 500)
#
# Run: 141, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 165.78, max: 500)
#
# Run: 142, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 164.94, max: 500)
#
# Run: 143, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 164.16, max: 500)
#
# Run: 144, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 162.96, max: 500)
#
# Run: 145, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 161.33, max: 500)
#
# Run: 146, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 159.92, max: 500)
#
# Run: 147, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 159.52, max: 500)
#
# Run: 148, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 158.28, max: 500)
#
# Run: 149, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 156.07, max: 500)
#
# Run: 150, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 154.79, max: 500)
#
# Run: 151, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 151.7, max: 500)
#
# Run: 152, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 147.01, max: 500)
#
# Run: 153, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 143.01, max: 500)
#
# Run: 154, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 142.96, max: 500)
#
# Run: 155, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 142.84, max: 500)
#
# Run: 156, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 137.94, max: 500)
#
# Run: 157, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 136.24, max: 500)
#
# Run: 158, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 131.38, max: 500)
#
# Run: 159, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 129.36, max: 500)
#
# Run: 160, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 124.45, max: 500)
#
# Run: 161, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 121.95, max: 500)
#
# Run: 162, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.05, max: 500)
#
# Run: 163, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 112.14, max: 500)
#
# Run: 164, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 107.24, max: 500)
#
# Run: 165, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 102.33, max: 500)
#
# Run: 166, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 97.43, max: 500)
#
# Run: 167, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 92.56, max: 500)
#
# Run: 168, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 87.74, max: 500)
#
# Run: 169, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 82.89, max: 500)
#
# Run: 170, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.98, max: 500)
#
# Run: 171, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 73.07, max: 500)
#
# Run: 172, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 71.14, max: 500)
#
# Run: 173, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 67.49, max: 500)
#
# Run: 174, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 65.17, max: 500)
#
# Run: 175, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 62.37, max: 500)
#
# Run: 176, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 57.62, max: 500)
#
# Run: 177, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 53.46, max: 500)
#
# Run: 178, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 48.82, max: 500)
#
# Run: 179, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 46.24, max: 500)
#
# Run: 180, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 41.51, max: 500)
#
# Run: 181, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 37.72, max: 500)
#
# Run: 182, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 35.37, max: 500)
#
# Run: 183, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 32.35, max: 500)
#
# Run: 184, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 28.51, max: 500)
#
# Run: 185, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 28.05, max: 500)
#
# Run: 186, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 28.03, max: 500)
#
# Run: 187, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 28.03, max: 500)
#
# Run: 188, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 31.3, max: 500)
#
# Run: 189, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 28.88, max: 500)
#
# Run: 190, exploration: 0.01, score: 421
# Scores: (min: 8, avg: 32.99, max: 500)
#
# Run: 191, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 33.96, max: 500)
# Run: 192, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 34.92, max: 500)
#
# Run: 193, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 35.98, max: 500)
#
# Run: 194, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 37.11, max: 500)
#
# Run: 195, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 38.9, max: 500)
#
# Run: 196, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 40.78, max: 500)
#
# Run: 197, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 42.21, max: 500)
#
# Run: 198, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 43.57, max: 500)
#
# Run: 199, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 45.36, max: 500)
#
# Run: 200, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 50.26, max: 500)
#
# Run: 201, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 55.16, max: 500)
#
# Run: 202, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 60.06, max: 500)
#
# Run: 203, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 64.96, max: 500)
#
# Run: 204, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 69.86, max: 500)
#
# Run: 205, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 74.77, max: 500)
#
# Run: 206, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 79.68, max: 500)
#
# Run: 207, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 84.6, max: 500)
#
# Run: 208, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 89.51, max: 500)
#
# Run: 209, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 94.42, max: 500)
#
# Run: 210, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 99.32, max: 500)
#
# Run: 211, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 104.23, max: 500)
#
# Run: 212, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 109.15, max: 500)
#
# Run: 213, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 114.05, max: 500)
#
# Run: 214, exploration: 0.01, score: 416
# Scores: (min: 8, avg: 118.11, max: 500)
#
# Run: 215, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 120.1, max: 500)
#
# Run: 216, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 125.01, max: 500)
#
# Run: 217, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 129.92, max: 500)
#
# Run: 218, exploration: 0.01, score: 293
# Scores: (min: 8, avg: 132.77, max: 500)
#
# Run: 219, exploration: 0.01, score: 268
# Scores: (min: 8, avg: 135.35, max: 500)
#
# Run: 220, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 136.74, max: 500)
#
# Run: 221, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 138.37, max: 500)
#
# Run: 222, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 140.42, max: 500)
#
# Run: 223, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 142.19, max: 500)
#
# Run: 224, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 144.12, max: 500)
#
# Run: 225, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 146.05, max: 500)
#
# Run: 226, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 148.1, max: 500)
#
# Run: 227, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 150.04, max: 500)
#
# Run: 228, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 151.75, max: 500)
#
# Run: 229, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 153.44, max: 500)
#
# Run: 230, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 154.97, max: 500)
#
# Run: 231, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 156.71, max: 500)
#
# Run: 232, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 158.68, max: 500)
#
# Run: 233, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 160.48, max: 500)
#
# Run: 234, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 162.61, max: 500)
#
# Run: 235, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 164.84, max: 500)
#
# Run: 236, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 166.62, max: 500)
#
# Run: 237, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 168.53, max: 500)
#
# Run: 238, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 170.58, max: 500)
#
# Run: 239, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 172.23, max: 500)
#
# Run: 240, exploration: 0.01, score: 298
# Scores: (min: 8, avg: 175.11, max: 500)
#
# Run: 241, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 177.42, max: 500)
#
# Run: 242, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 179.41, max: 500)
#
# Run: 243, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 181.63, max: 500)
#
# Run: 244, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 183.47, max: 500)
#
# Run: 245, exploration: 0.01, score: 253
# Scores: (min: 9, avg: 185.9, max: 500)
#
# Run: 246, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 187.51, max: 500)
#
# Run: 247, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 188.18, max: 500)
#
# Run: 248, exploration: 0.01, score: 259
# Scores: (min: 9, avg: 190.54, max: 500)
#
# Run: 249, exploration: 0.01, score: 283
# Scores: (min: 9, avg: 193.25, max: 500)
#
# Run: 250, exploration: 0.01, score: 248
# Scores: (min: 9, avg: 195.61, max: 500)
#
# Solved in 150 runs, 250 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-8-8f0d2ccc55bd> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
from scores.score_logger import ScoreLogger

# Modified cartpole: increased gamma to 0.995, increased exploration min to 0.5
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.995  
LEARNING_RATE = 0.001 
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.5 
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 12
# Scores: (min: 12, avg: 12, max: 12)
#
# Run: 2, exploration: 0.9558895783575597, score: 17
# Scores: (min: 12, avg: 14.5, max: 17)
#
# Run: 3, exploration: 0.8183201210226743, score: 32
# Scores: (min: 12, avg: 20.333333333333332, max: 32)
#
# Run: 4, exploration: 0.7402609576967045, score: 21
# Scores: (min: 12, avg: 20.5, max: 32)
#
# Run: 5, exploration: 0.6118738784280476, score: 39
# Scores: (min: 12, avg: 24.2, max: 39)
#
# Run: 6, exploration: 0.5819594443402982, score: 11
# Scores: (min: 11, avg: 22, max: 39)
#
# Run: 7, exploration: 0.500708706245853, score: 31
# Scores: (min: 11, avg: 23.285714285714285, max: 39)
#
# Run: 8, exploration: 0.5, score: 11
# Scores: (min: 11, avg: 21.75, max: 39)
#
# Run: 9, exploration: 0.5, score: 11
# Scores: (min: 11, avg: 20.555555555555557, max: 39)
#
# Run: 10, exploration: 0.5, score: 108
# Scores: (min: 11, avg: 29.3, max: 108)
#
# Run: 11, exploration: 0.5, score: 27
# Scores: (min: 11, avg: 29.09090909090909, max: 108)
#
# Run: 12, exploration: 0.5, score: 16
# Scores: (min: 11, avg: 28, max: 108)
#
# Run: 13, exploration: 0.5, score: 22
# Scores: (min: 11, avg: 27.53846153846154, max: 108)
#
# Run: 14, exploration: 0.5, score: 13
# Scores: (min: 11, avg: 26.5, max: 108)
#
# Run: 15, exploration: 0.5, score: 70
# Scores: (min: 11, avg: 29.4, max: 108)
#
# Run: 16, exploration: 0.5, score: 170
# Scores: (min: 11, avg: 38.1875, max: 170)
#
# Run: 17, exploration: 0.5, score: 57
# Scores: (min: 11, avg: 39.294117647058826, max: 170)
#
# Run: 18, exploration: 0.5, score: 26
# Scores: (min: 11, avg: 38.55555555555556, max: 170)
#
# Run: 19, exploration: 0.5, score: 51
# Scores: (min: 11, avg: 39.21052631578947, max: 170)
#
# Run: 20, exploration: 0.5, score: 77
# Scores: (min: 11, avg: 41.1, max: 170)
#
# Run: 21, exploration: 0.5, score: 70
# Scores: (min: 11, avg: 42.476190476190474, max: 170)
#
# Run: 22, exploration: 0.5, score: 43
# Scores: (min: 11, avg: 42.5, max: 170)
#
# Run: 23, exploration: 0.5, score: 68
# Scores: (min: 11, avg: 43.608695652173914, max: 170)
#
# Run: 24, exploration: 0.5, score: 64
# Scores: (min: 11, avg: 44.458333333333336, max: 170)
#
# Run: 25, exploration: 0.5, score: 68
# Scores: (min: 11, avg: 45.4, max: 170)
#
# Run: 26, exploration: 0.5, score: 72
# Scores: (min: 11, avg: 46.42307692307692, max: 170)
#
# Run: 27, exploration: 0.5, score: 92
# Scores: (min: 11, avg: 48.111111111111114, max: 170)
#
# Run: 28, exploration: 0.5, score: 38
# Scores: (min: 11, avg: 47.75, max: 170)
#
# Run: 29, exploration: 0.5, score: 111
# Scores: (min: 11, avg: 49.93103448275862, max: 170)
#
# Run: 30, exploration: 0.5, score: 75
# Scores: (min: 11, avg: 50.766666666666666, max: 170)
#
# Run: 31, exploration: 0.5, score: 41
# Scores: (min: 11, avg: 50.45161290322581, max: 170)
#
# Run: 32, exploration: 0.5, score: 81
# Scores: (min: 11, avg: 51.40625, max: 170)
#
# Run: 33, exploration: 0.5, score: 71
# Scores: (min: 11, avg: 52, max: 170)
#
# Run: 34, exploration: 0.5, score: 109
# Scores: (min: 11, avg: 53.6764705882353, max: 170)
#
# Run: 35, exploration: 0.5, score: 32
# Scores: (min: 11, avg: 53.05714285714286, max: 170)
#
# Run: 36, exploration: 0.5, score: 111
# Scores: (min: 11, avg: 54.666666666666664, max: 170)
#
# Run: 37, exploration: 0.5, score: 91
# Scores: (min: 11, avg: 55.648648648648646, max: 170)
#
# Run: 38, exploration: 0.5, score: 84
# Scores: (min: 11, avg: 56.39473684210526, max: 170)
#
# Run: 39, exploration: 0.5, score: 168
# Scores: (min: 11, avg: 59.256410256410255, max: 170)
#
# Run: 40, exploration: 0.5, score: 186
# Scores: (min: 11, avg: 62.425, max: 186)
#
# Run: 41, exploration: 0.5, score: 221
# Scores: (min: 11, avg: 66.29268292682927, max: 221)
#
# Run: 42, exploration: 0.5, score: 158
# Scores: (min: 11, avg: 68.47619047619048, max: 221)
#
# Run: 43, exploration: 0.5, score: 331
# Scores: (min: 11, avg: 74.5813953488372, max: 331)
#
# Run: 44, exploration: 0.5, score: 23
# Scores: (min: 11, avg: 73.4090909090909, max: 331)
#
# Run: 45, exploration: 0.5, score: 44
# Scores: (min: 11, avg: 72.75555555555556, max: 331)
#
# Run: 46, exploration: 0.5, score: 135
# Scores: (min: 11, avg: 74.1086956521739, max: 331)
#
# Run: 47, exploration: 0.5, score: 93
# Scores: (min: 11, avg: 74.51063829787235, max: 331)
#
# Run: 48, exploration: 0.5, score: 173
# Scores: (min: 11, avg: 76.5625, max: 331)
#
# Run: 49, exploration: 0.5, score: 90
# Scores: (min: 11, avg: 76.83673469387755, max: 331)
#
# Run: 50, exploration: 0.5, score: 52
# Scores: (min: 11, avg: 76.34, max: 331)
#
# Run: 51, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 84.6470588235294, max: 500)
#
# Run: 52, exploration: 0.5, score: 84
# Scores: (min: 11, avg: 84.63461538461539, max: 500)
#
# Run: 53, exploration: 0.5, score: 82
# Scores: (min: 11, avg: 84.58490566037736, max: 500)
#
# Run: 54, exploration: 0.5, score: 23
# Scores: (min: 11, avg: 83.44444444444444, max: 500)
#
# Run: 55, exploration: 0.5, score: 28
# Scores: (min: 11, avg: 82.43636363636364, max: 500)
#
# Run: 56, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 89.89285714285714, max: 500)
#
# Run: 57, exploration: 0.5, score: 176
# Scores: (min: 11, avg: 91.40350877192982, max: 500)
#
# Run: 58, exploration: 0.5, score: 165
# Scores: (min: 11, avg: 92.67241379310344, max: 500)
#
# Run: 59, exploration: 0.5, score: 213
# Scores: (min: 11, avg: 94.71186440677967, max: 500)
#
# Run: 60, exploration: 0.5, score: 54
# Scores: (min: 11, avg: 94.03333333333333, max: 500)
#
# Run: 61, exploration: 0.5, score: 138
# Scores: (min: 11, avg: 94.75409836065573, max: 500)
#
# Run: 62, exploration: 0.5, score: 291
# Scores: (min: 11, avg: 97.91935483870968, max: 500)
#
# Run: 63, exploration: 0.5, score: 16
# Scores: (min: 11, avg: 96.61904761904762, max: 500)
#
# Run: 64, exploration: 0.5, score: 82
# Scores: (min: 11, avg: 96.390625, max: 500)
#
# Run: 65, exploration: 0.5, score: 151
# Scores: (min: 11, avg: 97.23076923076923, max: 500)
#
# Run: 66, exploration: 0.5, score: 226
# Scores: (min: 11, avg: 99.18181818181819, max: 500)
#
# Run: 67, exploration: 0.5, score: 196
# Scores: (min: 11, avg: 100.6268656716418, max: 500)
#
# Run: 68, exploration: 0.5, score: 147
# Scores: (min: 11, avg: 101.30882352941177, max: 500)
#
# Run: 69, exploration: 0.5, score: 91
# Scores: (min: 11, avg: 101.15942028985508, max: 500)
#
# Run: 70, exploration: 0.5, score: 49
# Scores: (min: 11, avg: 100.41428571428571, max: 500)
#
# Run: 71, exploration: 0.5, score: 197
# Scores: (min: 11, avg: 101.77464788732394, max: 500)
#
# Run: 72, exploration: 0.5, score: 111
# Scores: (min: 11, avg: 101.90277777777777, max: 500)
#
# Run: 73, exploration: 0.5, score: 193
# Scores: (min: 11, avg: 103.15068493150685, max: 500)
#
# Run: 74, exploration: 0.5, score: 37
# Scores: (min: 11, avg: 102.25675675675676, max: 500)
#
# Run: 75, exploration: 0.5, score: 333
# Scores: (min: 11, avg: 105.33333333333333, max: 500)
#
# Run: 76, exploration: 0.5, score: 99
# Scores: (min: 11, avg: 105.25, max: 500)
#
# Run: 77, exploration: 0.5, score: 190
# Scores: (min: 11, avg: 106.35064935064935, max: 500)
#
# Run: 78, exploration: 0.5, score: 26
# Scores: (min: 11, avg: 105.32051282051282, max: 500)
#
# Run: 79, exploration: 0.5, score: 40
# Scores: (min: 11, avg: 104.49367088607595, max: 500)
#
# Run: 80, exploration: 0.5, score: 39
# Scores: (min: 11, avg: 103.675, max: 500)
#
# Run: 81, exploration: 0.5, score: 20
# Scores: (min: 11, avg: 102.64197530864197, max: 500)
#
# Run: 82, exploration: 0.5, score: 68
# Scores: (min: 11, avg: 102.21951219512195, max: 500)
#
# Run: 83, exploration: 0.5, score: 173
# Scores: (min: 11, avg: 103.07228915662651, max: 500)
#
# Run: 84, exploration: 0.5, score: 120
# Scores: (min: 11, avg: 103.27380952380952, max: 500)
#
# Run: 85, exploration: 0.5, score: 266
# Scores: (min: 11, avg: 105.18823529411765, max: 500)
#
# Run: 86, exploration: 0.5, score: 64
# Scores: (min: 11, avg: 104.70930232558139, max: 500)
#
# Run: 87, exploration: 0.5, score: 22
# Scores: (min: 11, avg: 103.75862068965517, max: 500)
#
# Run: 88, exploration: 0.5, score: 215
# Scores: (min: 11, avg: 105.02272727272727, max: 500)
#
# Run: 89, exploration: 0.5, score: 167
# Scores: (min: 11, avg: 105.71910112359551, max: 500)
#
# Run: 90, exploration: 0.5, score: 237
# Scores: (min: 11, avg: 107.17777777777778, max: 500)
#
# Run: 91, exploration: 0.5, score: 174
# Scores: (min: 11, avg: 107.91208791208791, max: 500)
#
# Run: 92, exploration: 0.5, score: 129
# Scores: (min: 11, avg: 108.1413043478261, max: 500)
#
# Run: 93, exploration: 0.5, score: 256
# Scores: (min: 11, avg: 109.73118279569893, max: 500)
# Run: 94, exploration: 0.5, score: 86
# Scores: (min: 11, avg: 109.47872340425532, max: 500)
#
# Run: 95, exploration: 0.5, score: 201
# Scores: (min: 11, avg: 110.4421052631579, max: 500)
#
# Run: 96, exploration: 0.5, score: 162
# Scores: (min: 11, avg: 110.97916666666667, max: 500)
#
# Run: 97, exploration: 0.5, score: 183
# Scores: (min: 11, avg: 111.72164948453609, max: 500)
#
# Run: 98, exploration: 0.5, score: 52
# Scores: (min: 11, avg: 111.11224489795919, max: 500)
#
# Run: 99, exploration: 0.5, score: 35
# Scores: (min: 11, avg: 110.34343434343434, max: 500)
#
# Run: 100, exploration: 0.5, score: 93
# Scores: (min: 11, avg: 110.17, max: 500)
#
# Run: 101, exploration: 0.5, score: 131
# Scores: (min: 11, avg: 111.36, max: 500)
#
# Run: 102, exploration: 0.5, score: 65
# Scores: (min: 11, avg: 111.84, max: 500)
#
# Run: 103, exploration: 0.5, score: 67
# Scores: (min: 11, avg: 112.19, max: 500)
#
# Run: 104, exploration: 0.5, score: 74
# Scores: (min: 11, avg: 112.72, max: 500)
#
# Run: 105, exploration: 0.5, score: 165
# Scores: (min: 11, avg: 113.98, max: 500)
#
# Run: 106, exploration: 0.5, score: 332
# Scores: (min: 11, avg: 117.19, max: 500)
#
# Run: 107, exploration: 0.5, score: 128
# Scores: (min: 11, avg: 118.16, max: 500)
#
# Run: 108, exploration: 0.5, score: 143
# Scores: (min: 11, avg: 119.48, max: 500)
#
# Run: 109, exploration: 0.5, score: 102
# Scores: (min: 13, avg: 120.39, max: 500)
#
# Run: 110, exploration: 0.5, score: 98
# Scores: (min: 13, avg: 120.29, max: 500)
#
# Run: 111, exploration: 0.5, score: 115
# Scores: (min: 13, avg: 121.17, max: 500)
#
# Run: 112, exploration: 0.5, score: 224
# Scores: (min: 13, avg: 123.25, max: 500)
#
# Run: 113, exploration: 0.5, score: 63
# Scores: (min: 13, avg: 123.66, max: 500)
#
# Run: 114, exploration: 0.5, score: 222
# Scores: (min: 16, avg: 125.75, max: 500)
#
# Run: 115, exploration: 0.5, score: 90
# Scores: (min: 16, avg: 125.95, max: 500)
#
# Run: 116, exploration: 0.5, score: 80
# Scores: (min: 16, avg: 125.05, max: 500)
#
# Run: 117, exploration: 0.5, score: 31
# Scores: (min: 16, avg: 124.79, max: 500)
#
# Run: 118, exploration: 0.5, score: 129
# Scores: (min: 16, avg: 125.82, max: 500)
#
# Run: 119, exploration: 0.5, score: 220
# Scores: (min: 16, avg: 127.51, max: 500)
#
# Run: 120, exploration: 0.5, score: 58
# Scores: (min: 16, avg: 127.32, max: 500)
#
# Run: 121, exploration: 0.5, score: 98
# Scores: (min: 16, avg: 127.6, max: 500)
#
# Run: 122, exploration: 0.5, score: 61
# Scores: (min: 16, avg: 127.78, max: 500)
#
# Run: 123, exploration: 0.5, score: 194
# Scores: (min: 16, avg: 129.04, max: 500)
#
# Run: 124, exploration: 0.5, score: 281
# Scores: (min: 16, avg: 131.21, max: 500)
#
# Run: 125, exploration: 0.5, score: 20
# Scores: (min: 16, avg: 130.73, max: 500)
#
# Run: 126, exploration: 0.5, score: 153
# Scores: (min: 16, avg: 131.54, max: 500)
#
# Run: 127, exploration: 0.5, score: 41
# Scores: (min: 16, avg: 131.03, max: 500)
#
# Run: 128, exploration: 0.5, score: 29
# Scores: (min: 16, avg: 130.94, max: 500)
#
# Run: 129, exploration: 0.5, score: 500
# Scores: (min: 16, avg: 134.83, max: 500)
#
# Run: 130, exploration: 0.5, score: 38
# Scores: (min: 16, avg: 134.46, max: 500)
#
# Run: 131, exploration: 0.5, score: 279
# Scores: (min: 16, avg: 136.84, max: 500)
#
# Run: 132, exploration: 0.5, score: 338
# Scores: (min: 16, avg: 139.41, max: 500)
#
# Run: 133, exploration: 0.5, score: 133
# Scores: (min: 16, avg: 140.03, max: 500)
#
# Run: 134, exploration: 0.5, score: 15
# Scores: (min: 15, avg: 139.09, max: 500)
#
# Run: 135, exploration: 0.5, score: 39
# Scores: (min: 15, avg: 139.16, max: 500)
#
# Run: 136, exploration: 0.5, score: 314
# Scores: (min: 15, avg: 141.19, max: 500)
#
# Run: 137, exploration: 0.5, score: 72
# Scores: (min: 15, avg: 141, max: 500)
#
# Run: 138, exploration: 0.5, score: 54
# Scores: (min: 15, avg: 140.7, max: 500)
#
# Run: 139, exploration: 0.5, score: 209
# Scores: (min: 15, avg: 141.11, max: 500)
#
# Run: 140, exploration: 0.5, score: 253
# Scores: (min: 15, avg: 141.78, max: 500)
#
# Run: 141, exploration: 0.5, score: 314
# Scores: (min: 15, avg: 142.71, max: 500)
#
# Run: 142, exploration: 0.5, score: 197
# Scores: (min: 15, avg: 143.1, max: 500)
#
# Run: 143, exploration: 0.5, score: 411
# Scores: (min: 15, avg: 143.9, max: 500)
#
# Run: 144, exploration: 0.5, score: 345
# Scores: (min: 15, avg: 147.12, max: 500)
#
# Run: 145, exploration: 0.5, score: 158
# Scores: (min: 15, avg: 148.26, max: 500)
#
# Run: 146, exploration: 0.5, score: 185
# Scores: (min: 15, avg: 148.76, max: 500)
#
# Run: 147, exploration: 0.5, score: 31
# Scores: (min: 15, avg: 148.14, max: 500)
#
# Run: 148, exploration: 0.5, score: 226
# Scores: (min: 15, avg: 148.67, max: 500)
#
# Run: 149, exploration: 0.5, score: 156
# Scores: (min: 15, avg: 149.33, max: 500)
#
# Run: 150, exploration: 0.5, score: 19
# Scores: (min: 15, avg: 149, max: 500)
#
# Run: 151, exploration: 0.5, score: 147
# Scores: (min: 15, avg: 145.47, max: 500)
#
# Run: 152, exploration: 0.5, score: 32
# Scores: (min: 15, avg: 144.95, max: 500)
#
# Run: 153, exploration: 0.5, score: 155
# Scores: (min: 15, avg: 145.68, max: 500)
#
# Run: 154, exploration: 0.5, score: 106
# Scores: (min: 15, avg: 146.51, max: 500)
#
# Run: 155, exploration: 0.5, score: 367
# Scores: (min: 15, avg: 149.9, max: 500)
#
# Run: 156, exploration: 0.5, score: 257
# Scores: (min: 15, avg: 147.47, max: 500)
#
# Run: 157, exploration: 0.5, score: 79
# Scores: (min: 15, avg: 146.5, max: 500)
#
# Run: 158, exploration: 0.5, score: 217
# Scores: (min: 15, avg: 147.02, max: 500)
#
# Run: 159, exploration: 0.5, score: 142
# Scores: (min: 15, avg: 146.31, max: 500)
#
# Run: 160, exploration: 0.5, score: 231
# Scores: (min: 15, avg: 148.08, max: 500)
#
# Run: 161, exploration: 0.5, score: 160
# Scores: (min: 15, avg: 148.3, max: 500)
#
# Run: 162, exploration: 0.5, score: 294
# Scores: (min: 15, avg: 148.33, max: 500)
#
# Run: 163, exploration: 0.5, score: 156
# Scores: (min: 15, avg: 149.73, max: 500)
#
# Run: 164, exploration: 0.5, score: 231
# Scores: (min: 15, avg: 151.22, max: 500)
#
# Run: 165, exploration: 0.5, score: 328
# Scores: (min: 15, avg: 152.99, max: 500)
#
# Run: 166, exploration: 0.5, score: 90
# Scores: (min: 15, avg: 151.63, max: 500)
#
# Run: 167, exploration: 0.5, score: 191
# Scores: (min: 15, avg: 151.58, max: 500)
#
# Run: 168, exploration: 0.5, score: 242
# Scores: (min: 15, avg: 152.53, max: 500)
#
# Run: 169, exploration: 0.5, score: 10
# Scores: (min: 10, avg: 151.72, max: 500)
#
# Run: 170, exploration: 0.5, score: 44
# Scores: (min: 10, avg: 151.67, max: 500)
#
# Run: 171, exploration: 0.5, score: 101
# Scores: (min: 10, avg: 150.71, max: 500)
#
# Run: 172, exploration: 0.5, score: 276
# Scores: (min: 10, avg: 152.36, max: 500)
#
# Run: 173, exploration: 0.5, score: 263
# Scores: (min: 10, avg: 153.06, max: 500)
#
# Run: 174, exploration: 0.5, score: 116
# Scores: (min: 10, avg: 153.85, max: 500)
#
# Run: 175, exploration: 0.5, score: 113
# Scores: (min: 10, avg: 151.65, max: 500)
#
# Run: 176, exploration: 0.5, score: 24
# Scores: (min: 10, avg: 150.9, max: 500)
#
# Run: 177, exploration: 0.5, score: 16
# Scores: (min: 10, avg: 149.16, max: 500)
#
# Run: 178, exploration: 0.5, score: 227
# Scores: (min: 10, avg: 151.17, max: 500)
#
# Run: 179, exploration: 0.5, score: 110
# Scores: (min: 10, avg: 151.87, max: 500)
#
# Run: 180, exploration: 0.5, score: 324
# Scores: (min: 10, avg: 154.72, max: 500)
#
# Run: 181, exploration: 0.5, score: 239
# Scores: (min: 10, avg: 156.91, max: 500)
#
# Run: 182, exploration: 0.5, score: 78
# Scores: (min: 10, avg: 157.01, max: 500)
#
# Run: 183, exploration: 0.5, score: 192
# Scores: (min: 10, avg: 157.2, max: 500)
#
# Run: 184, exploration: 0.5, score: 206
# Scores: (min: 10, avg: 158.06, max: 500)
#
# Run: 185, exploration: 0.5, score: 25
# Scores: (min: 10, avg: 155.65, max: 500)
#
# Run: 186, exploration: 0.5, score: 196
# Scores: (min: 10, avg: 156.97, max: 500)
#
# Run: 187, exploration: 0.5, score: 87
# Scores: (min: 10, avg: 157.62, max: 500)
#
# Run: 188, exploration: 0.5, score: 29
# Scores: (min: 10, avg: 155.76, max: 500)
#
# Run: 189, exploration: 0.5, score: 157
# Scores: (min: 10, avg: 155.66, max: 500)
#
# Run: 190, exploration: 0.5, score: 288
# Scores: (min: 10, avg: 156.17, max: 500)
#
# Run: 191, exploration: 0.5, score: 189
# Scores: (min: 10, avg: 156.32, max: 500)
#
# Run: 192, exploration: 0.5, score: 304
# Scores: (min: 10, avg: 158.07, max: 500)
#
# Run: 193, exploration: 0.5, score: 173
# Scores: (min: 10, avg: 157.24, max: 500)
#
# Run: 194, exploration: 0.5, score: 160
# Scores: (min: 10, avg: 157.98, max: 500)
# Run: 195, exploration: 0.5, score: 160
# Scores: (min: 10, avg: 157.57, max: 500)
#
# Run: 196, exploration: 0.5, score: 37
# Scores: (min: 10, avg: 156.32, max: 500)
#
# Run: 197, exploration: 0.5, score: 47
# Scores: (min: 10, avg: 154.96, max: 500)
#
# Run: 198, exploration: 0.5, score: 96
# Scores: (min: 10, avg: 155.4, max: 500)
#
# Run: 199, exploration: 0.5, score: 185
# Scores: (min: 10, avg: 156.9, max: 500)
#
# Run: 200, exploration: 0.5, score: 14
# Scores: (min: 10, avg: 156.11, max: 500)
#
# Run: 201, exploration: 0.5, score: 297
# Scores: (min: 10, avg: 157.77, max: 500)
#
# Run: 202, exploration: 0.5, score: 362
# Scores: (min: 10, avg: 160.74, max: 500)
#
# Run: 203, exploration: 0.5, score: 192
# Scores: (min: 10, avg: 161.99, max: 500)
#
# Run: 204, exploration: 0.5, score: 284
# Scores: (min: 10, avg: 164.09, max: 500)
#
# Run: 205, exploration: 0.5, score: 347
# Scores: (min: 10, avg: 165.91, max: 500)
#
# Run: 206, exploration: 0.5, score: 116
# Scores: (min: 10, avg: 163.75, max: 500)
#
# Run: 207, exploration: 0.5, score: 73
# Scores: (min: 10, avg: 163.2, max: 500)
#
# Run: 208, exploration: 0.5, score: 179
# Scores: (min: 10, avg: 163.56, max: 500)
#
# Run: 209, exploration: 0.5, score: 225
# Scores: (min: 10, avg: 164.79, max: 500)
#
# Run: 210, exploration: 0.5, score: 71
# Scores: (min: 10, avg: 164.52, max: 500)
#
# Run: 211, exploration: 0.5, score: 138
# Scores: (min: 10, avg: 164.75, max: 500)
#
# Run: 212, exploration: 0.5, score: 173
# Scores: (min: 10, avg: 164.24, max: 500)
#
# Run: 213, exploration: 0.5, score: 265
# Scores: (min: 10, avg: 166.26, max: 500)
#
# Run: 214, exploration: 0.5, score: 75
# Scores: (min: 10, avg: 164.79, max: 500)
#
# Run: 215, exploration: 0.5, score: 247
# Scores: (min: 10, avg: 166.36, max: 500)
#
# Run: 216, exploration: 0.5, score: 95
# Scores: (min: 10, avg: 166.51, max: 500)
#
# Run: 217, exploration: 0.5, score: 33
# Scores: (min: 10, avg: 166.53, max: 500)
#
# Run: 218, exploration: 0.5, score: 112
# Scores: (min: 10, avg: 166.36, max: 500)
#
# Run: 219, exploration: 0.5, score: 115
# Scores: (min: 10, avg: 165.31, max: 500)
#
# Run: 220, exploration: 0.5, score: 28
# Scores: (min: 10, avg: 165.01, max: 500)
#
# Run: 221, exploration: 0.5, score: 60
# Scores: (min: 10, avg: 164.63, max: 500)
#
# Run: 222, exploration: 0.5, score: 189
# Scores: (min: 10, avg: 165.91, max: 500)
#
# Run: 223, exploration: 0.5, score: 55
# Scores: (min: 10, avg: 164.52, max: 500)
#
# Run: 224, exploration: 0.5, score: 168
# Scores: (min: 10, avg: 163.39, max: 500)
#
# Run: 225, exploration: 0.5, score: 213
# Scores: (min: 10, avg: 165.32, max: 500)
#
# Run: 226, exploration: 0.5, score: 118
# Scores: (min: 10, avg: 164.97, max: 500)
#
# Run: 227, exploration: 0.5, score: 167
# Scores: (min: 10, avg: 166.23, max: 500)
#
# Run: 228, exploration: 0.5, score: 256
# Scores: (min: 10, avg: 168.5, max: 500)
#
# Run: 229, exploration: 0.5, score: 45
# Scores: (min: 10, avg: 163.95, max: 411)
#
# Run: 230, exploration: 0.5, score: 29
# Scores: (min: 10, avg: 163.86, max: 411)
#
# Run: 231, exploration: 0.5, score: 292
# Scores: (min: 10, avg: 163.99, max: 411)
#
# Run: 232, exploration: 0.5, score: 131
# Scores: (min: 10, avg: 161.92, max: 411)
#
# Run: 233, exploration: 0.5, score: 213
# Scores: (min: 10, avg: 162.72, max: 411)
#
# Run: 234, exploration: 0.5, score: 97
# Scores: (min: 10, avg: 163.54, max: 411)
#
# Run: 235, exploration: 0.5, score: 192
# Scores: (min: 10, avg: 165.07, max: 411)
#
# Run: 236, exploration: 0.5, score: 187
# Scores: (min: 10, avg: 163.8, max: 411)
#
# Run: 237, exploration: 0.5, score: 91
# Scores: (min: 10, avg: 163.99, max: 411)
#
# Run: 238, exploration: 0.5, score: 17
# Scores: (min: 10, avg: 163.62, max: 411)
#
# Run: 239, exploration: 0.5, score: 63
# Scores: (min: 10, avg: 162.16, max: 411)
#
# Run: 240, exploration: 0.5, score: 242
# Scores: (min: 10, avg: 162.05, max: 411)
#
# Run: 241, exploration: 0.5, score: 147
# Scores: (min: 10, avg: 160.38, max: 411)
#
# Run: 242, exploration: 0.5, score: 500
# Scores: (min: 10, avg: 163.41, max: 500)
#
# Run: 243, exploration: 0.5, score: 199
# Scores: (min: 10, avg: 161.29, max: 500)
#
# Run: 244, exploration: 0.5, score: 66
# Scores: (min: 10, avg: 158.5, max: 500)
#
# Run: 245, exploration: 0.5, score: 255
# Scores: (min: 10, avg: 159.47, max: 500)
#
# Run: 246, exploration: 0.5, score: 139
# Scores: (min: 10, avg: 159.01, max: 500)
#
# Run: 247, exploration: 0.5, score: 218
# Scores: (min: 10, avg: 160.88, max: 500)
#
# Run: 248, exploration: 0.5, score: 37
# Scores: (min: 10, avg: 158.99, max: 500)
#
# Run: 249, exploration: 0.5, score: 500
# Scores: (min: 10, avg: 162.43, max: 500)
#
# Run: 250, exploration: 0.5, score: 53
# Scores: (min: 10, avg: 162.77, max: 500)
#
# Run: 251, exploration: 0.5, score: 54
# Scores: (min: 10, avg: 161.84, max: 500)
#
# Run: 252, exploration: 0.5, score: 208
# Scores: (min: 10, avg: 163.6, max: 500)
#
# Run: 253, exploration: 0.5, score: 330
# Scores: (min: 10, avg: 165.35, max: 500)
#
# Run: 254, exploration: 0.5, score: 61
# Scores: (min: 10, avg: 164.9, max: 500)
#
# Run: 255, exploration: 0.5, score: 255
# Scores: (min: 10, avg: 163.78, max: 500)
#
# Run: 256, exploration: 0.5, score: 242
# Scores: (min: 10, avg: 163.63, max: 500)
#
# Run: 257, exploration: 0.5, score: 38
# Scores: (min: 10, avg: 163.22, max: 500)
#
# Run: 258, exploration: 0.5, score: 244
# Scores: (min: 10, avg: 163.49, max: 500)
#
# Run: 259, exploration: 0.5, score: 277
# Scores: (min: 10, avg: 164.84, max: 500)
#
# Run: 260, exploration: 0.5, score: 41
# Scores: (min: 10, avg: 162.94, max: 500)
#
# Run: 261, exploration: 0.5, score: 37
# Scores: (min: 10, avg: 161.71, max: 500)
#
# Run: 262, exploration: 0.5, score: 157
# Scores: (min: 10, avg: 160.34, max: 500)
#
# Run: 263, exploration: 0.5, score: 176
# Scores: (min: 10, avg: 160.54, max: 500)
#
# Run: 264, exploration: 0.5, score: 83
# Scores: (min: 10, avg: 159.06, max: 500)
#
# Run: 265, exploration: 0.5, score: 267
# Scores: (min: 10, avg: 158.45, max: 500)
#
# Run: 266, exploration: 0.5, score: 13
# Scores: (min: 10, avg: 157.68, max: 500)
#
# Run: 267, exploration: 0.5, score: 196
# Scores: (min: 10, avg: 157.73, max: 500)
#
# Run: 268, exploration: 0.5, score: 268
# Scores: (min: 10, avg: 157.99, max: 500)
#
# Run: 269, exploration: 0.5, score: 182
# Scores: (min: 13, avg: 159.71, max: 500)
#
# Run: 270, exploration: 0.5, score: 158
# Scores: (min: 13, avg: 160.85, max: 500)
#
# Run: 271, exploration: 0.5, score: 159
# Scores: (min: 13, avg: 161.43, max: 500)
#
# Run: 272, exploration: 0.5, score: 122
# Scores: (min: 13, avg: 159.89, max: 500)
#
# Run: 273, exploration: 0.5, score: 203
# Scores: (min: 13, avg: 159.29, max: 500)
#
# Run: 274, exploration: 0.5, score: 101
# Scores: (min: 13, avg: 159.14, max: 500)
#
# Run: 275, exploration: 0.5, score: 134
# Scores: (min: 13, avg: 159.35, max: 500)
#
# Run: 276, exploration: 0.5, score: 205
# Scores: (min: 13, avg: 161.16, max: 500)
#
# Run: 277, exploration: 0.5, score: 95
# Scores: (min: 13, avg: 161.95, max: 500)
#
# Run: 278, exploration: 0.5, score: 74
# Scores: (min: 13, avg: 160.42, max: 500)
#
# Run: 279, exploration: 0.5, score: 153
# Scores: (min: 13, avg: 160.85, max: 500)
#
# Run: 280, exploration: 0.5, score: 168
# Scores: (min: 13, avg: 159.29, max: 500)
#
# Run: 281, exploration: 0.5, score: 40
# Scores: (min: 13, avg: 157.3, max: 500)
#
# Run: 282, exploration: 0.5, score: 64
# Scores: (min: 13, avg: 157.16, max: 500)
#
# Run: 283, exploration: 0.5, score: 448
# Scores: (min: 13, avg: 159.72, max: 500)
#
# Run: 284, exploration: 0.5, score: 323
# Scores: (min: 13, avg: 160.89, max: 500)
#
# Run: 285, exploration: 0.5, score: 58
# Scores: (min: 13, avg: 161.22, max: 500)
#
# Run: 286, exploration: 0.5, score: 246
# Scores: (min: 13, avg: 161.72, max: 500)
#
# Run: 287, exploration: 0.5, score: 171
# Scores: (min: 13, avg: 162.56, max: 500)
#
# Run: 288, exploration: 0.5, score: 67
# Scores: (min: 13, avg: 162.94, max: 500)
#
# Run: 289, exploration: 0.5, score: 259
# Scores: (min: 13, avg: 163.96, max: 500)
#
# Run: 290, exploration: 0.5, score: 187
# Scores: (min: 13, avg: 162.95, max: 500)
#
# Run: 291, exploration: 0.5, score: 46
# Scores: (min: 13, avg: 161.52, max: 500)
#
# Run: 292, exploration: 0.5, score: 193
# Scores: (min: 13, avg: 160.41, max: 500)
#
# Run: 293, exploration: 0.5, score: 235
# Scores: (min: 13, avg: 161.03, max: 500)
#
# Run: 294, exploration: 0.5, score: 319
# Scores: (min: 13, avg: 162.62, max: 500)
#
# Run: 295, exploration: 0.5, score: 38
# Scores: (min: 13, avg: 161.4, max: 500)
#
# Run: 296, exploration: 0.5, score: 186
# Scores: (min: 13, avg: 162.89, max: 500)
# Run: 297, exploration: 0.5, score: 12
# Scores: (min: 12, avg: 162.54, max: 500)
#
# Run: 298, exploration: 0.5, score: 271
# Scores: (min: 12, avg: 164.29, max: 500)
#
# Run: 299, exploration: 0.5, score: 59
# Scores: (min: 12, avg: 163.03, max: 500)
#
# Run: 300, exploration: 0.5, score: 96
# Scores: (min: 12, avg: 163.85, max: 500)
#
# Run: 301, exploration: 0.5, score: 215
# Scores: (min: 12, avg: 163.03, max: 500)
#
# Run: 302, exploration: 0.5, score: 100
# Scores: (min: 12, avg: 160.41, max: 500)
#
# Run: 303, exploration: 0.5, score: 177
# Scores: (min: 12, avg: 160.26, max: 500)
#
# Run: 304, exploration: 0.5, score: 257
# Scores: (min: 12, avg: 159.99, max: 500)
#
# Run: 305, exploration: 0.5, score: 176
# Scores: (min: 12, avg: 158.28, max: 500)
#
# Run: 306, exploration: 0.5, score: 176
# Scores: (min: 12, avg: 158.88, max: 500)
#
# Run: 307, exploration: 0.5, score: 109
# Scores: (min: 12, avg: 159.24, max: 500)
#
# Run: 308, exploration: 0.5, score: 123
# Scores: (min: 12, avg: 158.68, max: 500)
#
# Run: 309, exploration: 0.5, score: 264
# Scores: (min: 12, avg: 159.07, max: 500)
#
# Run: 310, exploration: 0.5, score: 228
# Scores: (min: 12, avg: 160.64, max: 500)
#
# Run: 311, exploration: 0.5, score: 191
# Scores: (min: 12, avg: 161.17, max: 500)
#
# Run: 312, exploration: 0.5, score: 264
# Scores: (min: 12, avg: 162.08, max: 500)
#
# Run: 313, exploration: 0.5, score: 59
# Scores: (min: 12, avg: 160.02, max: 500)
#
# Run: 314, exploration: 0.5, score: 83
# Scores: (min: 12, avg: 160.1, max: 500)
#
# Run: 315, exploration: 0.5, score: 14
# Scores: (min: 12, avg: 157.77, max: 500)
#
# Run: 316, exploration: 0.5, score: 81
# Scores: (min: 12, avg: 157.63, max: 500)
#
# Run: 317, exploration: 0.5, score: 287
# Scores: (min: 12, avg: 160.17, max: 500)
#
# Run: 318, exploration: 0.5, score: 342
# Scores: (min: 12, avg: 162.47, max: 500)
#
# Run: 319, exploration: 0.5, score: 71
# Scores: (min: 12, avg: 162.03, max: 500)
#
# Run: 320, exploration: 0.5, score: 78
# Scores: (min: 12, avg: 162.53, max: 500)
#
# Run: 321, exploration: 0.5, score: 113
# Scores: (min: 12, avg: 163.06, max: 500)
#
# Run: 322, exploration: 0.5, score: 18
# Scores: (min: 12, avg: 161.35, max: 500)
#
# Run: 323, exploration: 0.5, score: 147
# Scores: (min: 12, avg: 162.27, max: 500)
#
# Run: 324, exploration: 0.5, score: 288
# Scores: (min: 12, avg: 163.47, max: 500)
#
# Run: 325, exploration: 0.5, score: 143
# Scores: (min: 12, avg: 162.77, max: 500)
#
# Run: 326, exploration: 0.5, score: 99
# Scores: (min: 12, avg: 162.58, max: 500)
#
# Run: 327, exploration: 0.5, score: 242
# Scores: (min: 12, avg: 163.33, max: 500)
#
# Run: 328, exploration: 0.5, score: 178
# Scores: (min: 12, avg: 162.55, max: 500)
#
# Run: 329, exploration: 0.5, score: 236
# Scores: (min: 12, avg: 164.46, max: 500)
#
# Run: 330, exploration: 0.5, score: 124
# Scores: (min: 12, avg: 165.41, max: 500)
#
# Run: 331, exploration: 0.5, score: 19
# Scores: (min: 12, avg: 162.68, max: 500)
#
# Run: 332, exploration: 0.5, score: 83
# Scores: (min: 12, avg: 162.2, max: 500)
#
# Run: 333, exploration: 0.5, score: 98
# Scores: (min: 12, avg: 161.05, max: 500)
#
# Run: 334, exploration: 0.5, score: 47
# Scores: (min: 12, avg: 160.55, max: 500)
#
# Run: 335, exploration: 0.5, score: 133
# Scores: (min: 12, avg: 159.96, max: 500)
#
# Run: 336, exploration: 0.5, score: 200
# Scores: (min: 12, avg: 160.09, max: 500)
#
# Run: 337, exploration: 0.5, score: 163
# Scores: (min: 12, avg: 160.81, max: 500)
#
# Run: 338, exploration: 0.5, score: 58
# Scores: (min: 12, avg: 161.22, max: 500)
#
# Run: 339, exploration: 0.5, score: 111
# Scores: (min: 12, avg: 161.7, max: 500)
#
# Run: 340, exploration: 0.5, score: 301
# Scores: (min: 12, avg: 162.29, max: 500)
#
# Run: 341, exploration: 0.5, score: 21
# Scores: (min: 12, avg: 161.03, max: 500)
#
# Run: 342, exploration: 0.5, score: 16
# Scores: (min: 12, avg: 156.19, max: 500)
#
# Run: 343, exploration: 0.5, score: 42
# Scores: (min: 12, avg: 154.62, max: 500)
#
# Run: 344, exploration: 0.5, score: 137
# Scores: (min: 12, avg: 155.33, max: 500)
#
# Run: 345, exploration: 0.5, score: 189
# Scores: (min: 12, avg: 154.67, max: 500)
#
# Run: 346, exploration: 0.5, score: 119
# Scores: (min: 12, avg: 154.47, max: 500)
#
# Run: 347, exploration: 0.5, score: 232
# Scores: (min: 12, avg: 154.61, max: 500)
#
# Run: 348, exploration: 0.5, score: 127
# Scores: (min: 12, avg: 155.51, max: 500)
#
# Run: 349, exploration: 0.5, score: 180
# Scores: (min: 12, avg: 152.31, max: 448)
#
# Run: 350, exploration: 0.5, score: 163
# Scores: (min: 12, avg: 153.41, max: 448)
#
# Run: 351, exploration: 0.5, score: 16
# Scores: (min: 12, avg: 153.03, max: 448)
#
# Run: 352, exploration: 0.5, score: 298
# Scores: (min: 12, avg: 153.93, max: 448)
#
# Run: 353, exploration: 0.5, score: 203
# Scores: (min: 12, avg: 152.66, max: 448)
#
# Run: 354, exploration: 0.5, score: 62
# Scores: (min: 12, avg: 152.67, max: 448)
#
# Run: 355, exploration: 0.5, score: 75
# Scores: (min: 12, avg: 150.87, max: 448)
#
# Run: 356, exploration: 0.5, score: 178
# Scores: (min: 12, avg: 150.23, max: 448)
#
# Run: 357, exploration: 0.5, score: 170
# Scores: (min: 12, avg: 151.55, max: 448)
#
# Run: 358, exploration: 0.5, score: 93
# Scores: (min: 12, avg: 150.04, max: 448)
#
# Run: 359, exploration: 0.5, score: 76
# Scores: (min: 12, avg: 148.03, max: 448)
#
# Run: 360, exploration: 0.5, score: 127
# Scores: (min: 12, avg: 148.89, max: 448)
#
# Run: 361, exploration: 0.5, score: 247
# Scores: (min: 12, avg: 150.99, max: 448)
#
# Run: 362, exploration: 0.5, score: 183
# Scores: (min: 12, avg: 151.25, max: 448)
#
# Run: 363, exploration: 0.5, score: 142
# Scores: (min: 12, avg: 150.91, max: 448)
#
# Run: 364, exploration: 0.5, score: 119
# Scores: (min: 12, avg: 151.27, max: 448)
#
# Run: 365, exploration: 0.5, score: 197
# Scores: (min: 12, avg: 150.57, max: 448)
#
# Run: 366, exploration: 0.5, score: 149
# Scores: (min: 12, avg: 151.93, max: 448)
#
# Run: 367, exploration: 0.5, score: 154
# Scores: (min: 12, avg: 151.51, max: 448)
#
# Run: 368, exploration: 0.5, score: 156
# Scores: (min: 12, avg: 150.39, max: 448)
#
# Run: 369, exploration: 0.5, score: 54
# Scores: (min: 12, avg: 149.11, max: 448)
#
# Run: 370, exploration: 0.5, score: 182
# Scores: (min: 12, avg: 149.35, max: 448)
#
# Run: 371, exploration: 0.5, score: 85
# Scores: (min: 12, avg: 148.61, max: 448)
#
# Run: 372, exploration: 0.5, score: 129
# Scores: (min: 12, avg: 148.68, max: 448)
#
# Run: 373, exploration: 0.5, score: 198
# Scores: (min: 12, avg: 148.63, max: 448)
#
# Run: 374, exploration: 0.5, score: 249
# Scores: (min: 12, avg: 150.11, max: 448)
#
# Run: 375, exploration: 0.5, score: 208
# Scores: (min: 12, avg: 150.85, max: 448)
#
# Run: 376, exploration: 0.5, score: 100
# Scores: (min: 12, avg: 149.8, max: 448)
#
# Run: 377, exploration: 0.5, score: 189
# Scores: (min: 12, avg: 150.74, max: 448)
#
# Run: 378, exploration: 0.5, score: 143
# Scores: (min: 12, avg: 151.43, max: 448)
#
# Run: 379, exploration: 0.5, score: 140
# Scores: (min: 12, avg: 151.3, max: 448)
#
# Run: 380, exploration: 0.5, score: 97
# Scores: (min: 12, avg: 150.59, max: 448)
#
# Run: 381, exploration: 0.5, score: 19
# Scores: (min: 12, avg: 150.38, max: 448)
#
# Run: 382, exploration: 0.5, score: 61
# Scores: (min: 12, avg: 150.35, max: 448)
#
# Run: 383, exploration: 0.5, score: 115
# Scores: (min: 12, avg: 147.02, max: 342)
#
# Run: 384, exploration: 0.5, score: 314
# Scores: (min: 12, avg: 146.93, max: 342)
#
# Run: 385, exploration: 0.5, score: 180
# Scores: (min: 12, avg: 148.15, max: 342)
#
# Run: 386, exploration: 0.5, score: 218
# Scores: (min: 12, avg: 147.87, max: 342)
#
# Run: 387, exploration: 0.5, score: 47
# Scores: (min: 12, avg: 146.63, max: 342)
#
# Run: 388, exploration: 0.5, score: 176
# Scores: (min: 12, avg: 147.72, max: 342)
#
# Run: 389, exploration: 0.5, score: 178
# Scores: (min: 12, avg: 146.91, max: 342)
#
# Run: 390, exploration: 0.5, score: 271
# Scores: (min: 12, avg: 147.75, max: 342)
#
# Run: 391, exploration: 0.5, score: 27
# Scores: (min: 12, avg: 147.56, max: 342)
#
# Run: 392, exploration: 0.5, score: 236
# Scores: (min: 12, avg: 147.99, max: 342)
#
# Run: 393, exploration: 0.5, score: 66
# Scores: (min: 12, avg: 146.3, max: 342)
#
# Run: 394, exploration: 0.5, score: 247
# Scores: (min: 12, avg: 145.58, max: 342)
#
# Run: 395, exploration: 0.5, score: 313
# Scores: (min: 12, avg: 148.33, max: 342)
#
# Run: 396, exploration: 0.5, score: 299
# Scores: (min: 12, avg: 149.46, max: 342)
#
# Run: 397, exploration: 0.5, score: 174
# Scores: (min: 14, avg: 151.08, max: 342)
#
# Run: 398, exploration: 0.5, score: 282
# Scores: (min: 14, avg: 151.19, max: 342)
# Run: 399, exploration: 0.5, score: 81
# Scores: (min: 14, avg: 151.41, max: 342)
#
# Run: 400, exploration: 0.5, score: 30
# Scores: (min: 14, avg: 150.75, max: 342)
#
# Run: 401, exploration: 0.5, score: 80
# Scores: (min: 14, avg: 149.4, max: 342)
#
# Run: 402, exploration: 0.5, score: 223
# Scores: (min: 14, avg: 150.63, max: 342)
#
# Run: 403, exploration: 0.5, score: 321
# Scores: (min: 14, avg: 152.07, max: 342)
#
# Run: 404, exploration: 0.5, score: 265
# Scores: (min: 14, avg: 152.15, max: 342)
#
# Run: 405, exploration: 0.5, score: 242
# Scores: (min: 14, avg: 152.81, max: 342)
#
# Run: 406, exploration: 0.5, score: 280
# Scores: (min: 14, avg: 153.85, max: 342)
#
# Run: 407, exploration: 0.5, score: 35
# Scores: (min: 14, avg: 153.11, max: 342)
#
# Run: 408, exploration: 0.5, score: 176
# Scores: (min: 14, avg: 153.64, max: 342)
#
# Run: 409, exploration: 0.5, score: 26
# Scores: (min: 14, avg: 151.26, max: 342)
#
# Run: 410, exploration: 0.5, score: 396
# Scores: (min: 14, avg: 152.94, max: 396)
#
# Run: 411, exploration: 0.5, score: 12
# Scores: (min: 12, avg: 151.15, max: 396)
#
# Run: 412, exploration: 0.5, score: 112
# Scores: (min: 12, avg: 149.63, max: 396)
#
# Run: 413, exploration: 0.5, score: 113
# Scores: (min: 12, avg: 150.17, max: 396)
#
# Run: 414, exploration: 0.5, score: 198
# Scores: (min: 12, avg: 151.32, max: 396)
#
# Run: 415, exploration: 0.5, score: 202
# Scores: (min: 12, avg: 153.2, max: 396)
#
# Run: 416, exploration: 0.5, score: 251
# Scores: (min: 12, avg: 154.9, max: 396)
#
# Run: 417, exploration: 0.5, score: 59
# Scores: (min: 12, avg: 152.62, max: 396)
#
# Run: 418, exploration: 0.5, score: 208
# Scores: (min: 12, avg: 151.28, max: 396)
#
# Run: 419, exploration: 0.5, score: 440
# Scores: (min: 12, avg: 154.97, max: 440)
#
# Run: 420, exploration: 0.5, score: 106
# Scores: (min: 12, avg: 155.25, max: 440)
#
# Run: 421, exploration: 0.5, score: 267
# Scores: (min: 12, avg: 156.79, max: 440)
#
# Run: 422, exploration: 0.5, score: 45
# Scores: (min: 12, avg: 157.06, max: 440)
#
# Run: 423, exploration: 0.5, score: 50
# Scores: (min: 12, avg: 156.09, max: 440)
#
# Run: 424, exploration: 0.5, score: 485
# Scores: (min: 12, avg: 158.06, max: 485)
#
# Run: 425, exploration: 0.5, score: 500
# Scores: (min: 12, avg: 161.63, max: 500)
#
# Run: 426, exploration: 0.5, score: 41
# Scores: (min: 12, avg: 161.05, max: 500)
#
# Run: 427, exploration: 0.5, score: 225
# Scores: (min: 12, avg: 160.88, max: 500)
#
# Run: 428, exploration: 0.5, score: 272
# Scores: (min: 12, avg: 161.82, max: 500)
#
# Run: 429, exploration: 0.5, score: 58
# Scores: (min: 12, avg: 160.04, max: 500)
#
# Run: 430, exploration: 0.5, score: 193
# Scores: (min: 12, avg: 160.73, max: 500)
#
# Run: 431, exploration: 0.5, score: 145
# Scores: (min: 12, avg: 161.99, max: 500)
#
# Run: 432, exploration: 0.5, score: 68
# Scores: (min: 12, avg: 161.84, max: 500)
#
# Run: 433, exploration: 0.5, score: 51
# Scores: (min: 12, avg: 161.37, max: 500)
#
# Run: 434, exploration: 0.5, score: 183
# Scores: (min: 12, avg: 162.73, max: 500)
#
# Run: 435, exploration: 0.5, score: 220
# Scores: (min: 12, avg: 163.6, max: 500)
#
# Run: 436, exploration: 0.5, score: 144
# Scores: (min: 12, avg: 163.04, max: 500)
#
# Run: 437, exploration: 0.5, score: 124
# Scores: (min: 12, avg: 162.65, max: 500)
#
# Run: 438, exploration: 0.5, score: 35
# Scores: (min: 12, avg: 162.42, max: 500)
#
# Run: 439, exploration: 0.5, score: 30
# Scores: (min: 12, avg: 161.61, max: 500)
#
# Run: 440, exploration: 0.5, score: 194
# Scores: (min: 12, avg: 160.54, max: 500)
#
# Run: 441, exploration: 0.5, score: 19
# Scores: (min: 12, avg: 160.52, max: 500)
#
# Run: 442, exploration: 0.5, score: 202
# Scores: (min: 12, avg: 162.38, max: 500)
#
# Run: 443, exploration: 0.5, score: 47
# Scores: (min: 12, avg: 162.43, max: 500)
#
# Run: 444, exploration: 0.5, score: 48
# Scores: (min: 12, avg: 161.54, max: 500)
#
# Run: 445, exploration: 0.5, score: 75
# Scores: (min: 12, avg: 160.4, max: 500)
#
# Run: 446, exploration: 0.5, score: 172
# Scores: (min: 12, avg: 160.93, max: 500)
#
# Run: 447, exploration: 0.5, score: 17
# Scores: (min: 12, avg: 158.78, max: 500)
#
# Run: 448, exploration: 0.5, score: 142
# Scores: (min: 12, avg: 158.93, max: 500)
#
# Run: 449, exploration: 0.5, score: 46
# Scores: (min: 12, avg: 157.59, max: 500)
#
# Run: 450, exploration: 0.5, score: 68
# Scores: (min: 12, avg: 156.64, max: 500)
#
# Run: 451, exploration: 0.5, score: 202
# Scores: (min: 12, avg: 158.5, max: 500)
#
# Run: 452, exploration: 0.5, score: 134
# Scores: (min: 12, avg: 156.86, max: 500)
#
# Run: 453, exploration: 0.5, score: 299
# Scores: (min: 12, avg: 157.82, max: 500)
#
# Run: 454, exploration: 0.5, score: 263
# Scores: (min: 12, avg: 159.83, max: 500)
#
# Run: 455, exploration: 0.5, score: 234
# Scores: (min: 12, avg: 161.42, max: 500)
#
# Run: 456, exploration: 0.5, score: 500
# Scores: (min: 12, avg: 164.64, max: 500)
#
# Run: 457, exploration: 0.5, score: 15
# Scores: (min: 12, avg: 163.09, max: 500)
#
# Run: 458, exploration: 0.5, score: 308
# Scores: (min: 12, avg: 165.24, max: 500)
#
# Run: 459, exploration: 0.5, score: 107
# Scores: (min: 12, avg: 165.55, max: 500)
#
# Run: 460, exploration: 0.5, score: 89
# Scores: (min: 12, avg: 165.17, max: 500)
#
# Run: 461, exploration: 0.5, score: 36
# Scores: (min: 12, avg: 163.06, max: 500)
#
# Run: 462, exploration: 0.5, score: 38
# Scores: (min: 12, avg: 161.61, max: 500)
#
# Run: 463, exploration: 0.5, score: 39
# Scores: (min: 12, avg: 160.58, max: 500)
#
# Run: 464, exploration: 0.5, score: 111
# Scores: (min: 12, avg: 160.5, max: 500)
#
# Run: 465, exploration: 0.5, score: 96
# Scores: (min: 12, avg: 159.49, max: 500)
#
# Run: 466, exploration: 0.5, score: 132
# Scores: (min: 12, avg: 159.32, max: 500)
#
# Run: 467, exploration: 0.5, score: 272
# Scores: (min: 12, avg: 160.5, max: 500)
#
# Run: 468, exploration: 0.5, score: 32
# Scores: (min: 12, avg: 159.26, max: 500)
#
# Run: 469, exploration: 0.5, score: 137
# Scores: (min: 12, avg: 160.09, max: 500)
#
# Run: 470, exploration: 0.5, score: 260
# Scores: (min: 12, avg: 160.87, max: 500)
#
# Run: 471, exploration: 0.5, score: 39
# Scores: (min: 12, avg: 160.41, max: 500)
#
# Run: 472, exploration: 0.5, score: 31
# Scores: (min: 12, avg: 159.43, max: 500)
#
# Run: 473, exploration: 0.5, score: 249
# Scores: (min: 12, avg: 159.94, max: 500)
#
# Run: 474, exploration: 0.5, score: 89
# Scores: (min: 12, avg: 158.34, max: 500)
#
# Run: 475, exploration: 0.5, score: 103
# Scores: (min: 12, avg: 157.29, max: 500)
#
# Run: 476, exploration: 0.5, score: 124
# Scores: (min: 12, avg: 157.53, max: 500)
#
# Run: 477, exploration: 0.5, score: 388
# Scores: (min: 12, avg: 159.52, max: 500)
#
# Run: 478, exploration: 0.5, score: 73
# Scores: (min: 12, avg: 158.82, max: 500)
#
# Run: 479, exploration: 0.5, score: 270
# Scores: (min: 12, avg: 160.12, max: 500)
#
# Run: 480, exploration: 0.5, score: 363
# Scores: (min: 12, avg: 162.78, max: 500)
#
# Run: 481, exploration: 0.5, score: 71
# Scores: (min: 12, avg: 163.3, max: 500)
#
# Run: 482, exploration: 0.5, score: 291
# Scores: (min: 12, avg: 165.6, max: 500)
#
# Run: 483, exploration: 0.5, score: 192
# Scores: (min: 12, avg: 166.37, max: 500)
#
# Run: 484, exploration: 0.5, score: 140
# Scores: (min: 12, avg: 164.63, max: 500)
#
# Run: 485, exploration: 0.5, score: 72
# Scores: (min: 12, avg: 163.55, max: 500)
#
# Run: 486, exploration: 0.5, score: 345
# Scores: (min: 12, avg: 164.82, max: 500)
#
# Run: 487, exploration: 0.5, score: 59
# Scores: (min: 12, avg: 164.94, max: 500)
#
# Run: 488, exploration: 0.5, score: 43
# Scores: (min: 12, avg: 163.61, max: 500)
#
# Run: 489, exploration: 0.5, score: 206
# Scores: (min: 12, avg: 163.89, max: 500)
#
# Run: 490, exploration: 0.5, score: 366
# Scores: (min: 12, avg: 164.84, max: 500)
#
# Run: 491, exploration: 0.5, score: 279
# Scores: (min: 12, avg: 167.36, max: 500)
#
# Run: 492, exploration: 0.5, score: 76
# Scores: (min: 12, avg: 165.76, max: 500)
#
# Run: 493, exploration: 0.5, score: 45
# Scores: (min: 12, avg: 165.55, max: 500)
#
# Run: 494, exploration: 0.5, score: 74
# Scores: (min: 12, avg: 163.82, max: 500)
#
# Run: 495, exploration: 0.5, score: 460
# Scores: (min: 12, avg: 165.29, max: 500)
#
# Run: 496, exploration: 0.5, score: 334
# Scores: (min: 12, avg: 165.64, max: 500)
#
# Run: 497, exploration: 0.5, score: 75
# Scores: (min: 12, avg: 164.65, max: 500)
#
# Run: 498, exploration: 0.5, score: 78
# Scores: (min: 12, avg: 162.61, max: 500)
#
# Run: 499, exploration: 0.5, score: 70
# Scores: (min: 12, avg: 162.5, max: 500)
#
# Run: 500, exploration: 0.5, score: 190
# Scores: (min: 12, avg: 164.1, max: 500)
# Run: 501, exploration: 0.5, score: 78
# Scores: (min: 12, avg: 164.08, max: 500)
#
# Run: 502, exploration: 0.5, score: 116
# Scores: (min: 12, avg: 163.01, max: 500)
#
# Run: 503, exploration: 0.5, score: 188
# Scores: (min: 12, avg: 161.68, max: 500)
#
# Run: 504, exploration: 0.5, score: 500
# Scores: (min: 12, avg: 164.03, max: 500)
#
# Run: 505, exploration: 0.5, score: 177
# Scores: (min: 12, avg: 163.38, max: 500)
#
# Run: 506, exploration: 0.5, score: 61
# Scores: (min: 12, avg: 161.19, max: 500)
#
# Run: 507, exploration: 0.5, score: 71
# Scores: (min: 12, avg: 161.55, max: 500)
#
# Run: 508, exploration: 0.5, score: 228
# Scores: (min: 12, avg: 162.07, max: 500)
#
# Run: 509, exploration: 0.5, score: 150
# Scores: (min: 12, avg: 163.31, max: 500)
#
# Run: 510, exploration: 0.5, score: 66
# Scores: (min: 12, avg: 160.01, max: 500)
#
# Run: 511, exploration: 0.5, score: 456
# Scores: (min: 15, avg: 164.45, max: 500)
#
# Run: 512, exploration: 0.5, score: 326
# Scores: (min: 15, avg: 166.59, max: 500)
#
# Run: 513, exploration: 0.5, score: 342
# Scores: (min: 15, avg: 168.88, max: 500)
#
# Run: 514, exploration: 0.5, score: 44
# Scores: (min: 15, avg: 167.34, max: 500)
#
# Run: 515, exploration: 0.5, score: 34
# Scores: (min: 15, avg: 165.66, max: 500)
#
# Run: 516, exploration: 0.5, score: 308
# Scores: (min: 15, avg: 166.23, max: 500)
#
# Run: 517, exploration: 0.5, score: 25
# Scores: (min: 15, avg: 165.89, max: 500)
#
# Run: 518, exploration: 0.5, score: 357
# Scores: (min: 15, avg: 167.38, max: 500)
#
# Run: 519, exploration: 0.5, score: 328
# Scores: (min: 15, avg: 166.26, max: 500)
#
# Run: 520, exploration: 0.5, score: 147
# Scores: (min: 15, avg: 166.67, max: 500)
#
# Run: 521, exploration: 0.5, score: 131
# Scores: (min: 15, avg: 165.31, max: 500)
#
# Run: 522, exploration: 0.5, score: 272
# Scores: (min: 15, avg: 167.58, max: 500)
#
# Run: 523, exploration: 0.5, score: 93
# Scores: (min: 15, avg: 168.01, max: 500)
#
# Run: 524, exploration: 0.5, score: 35
# Scores: (min: 15, avg: 163.51, max: 500)
#
# Run: 525, exploration: 0.5, score: 137
# Scores: (min: 15, avg: 159.88, max: 500)
#
# Run: 526, exploration: 0.5, score: 120
# Scores: (min: 15, avg: 160.67, max: 500)
#
# Run: 527, exploration: 0.5, score: 500
# Scores: (min: 15, avg: 163.42, max: 500)
#
# Run: 528, exploration: 0.5, score: 193
# Scores: (min: 15, avg: 162.63, max: 500)
#
# Run: 529, exploration: 0.5, score: 110
# Scores: (min: 15, avg: 163.15, max: 500)
#
# Run: 530, exploration: 0.5, score: 89
# Scores: (min: 15, avg: 162.11, max: 500)
#
# Run: 531, exploration: 0.5, score: 53
# Scores: (min: 15, avg: 161.19, max: 500)
#
# Run: 532, exploration: 0.5, score: 109
# Scores: (min: 15, avg: 161.6, max: 500)
#
# Run: 533, exploration: 0.5, score: 458
# Scores: (min: 15, avg: 165.67, max: 500)
#
# Run: 534, exploration: 0.5, score: 253
# Scores: (min: 15, avg: 166.37, max: 500)
#
# Run: 535, exploration: 0.5, score: 401
# Scores: (min: 15, avg: 168.18, max: 500)
#
# Run: 536, exploration: 0.5, score: 239
# Scores: (min: 15, avg: 169.13, max: 500)
#
# Run: 537, exploration: 0.5, score: 30
# Scores: (min: 15, avg: 168.19, max: 500)
#
# Run: 538, exploration: 0.5, score: 112
# Scores: (min: 15, avg: 168.96, max: 500)
#
# Run: 539, exploration: 0.5, score: 154
# Scores: (min: 15, avg: 170.2, max: 500)
#
# Run: 540, exploration: 0.5, score: 337
# Scores: (min: 15, avg: 171.63, max: 500)
#
# Run: 541, exploration: 0.5, score: 350
# Scores: (min: 15, avg: 174.94, max: 500)
#
# Run: 542, exploration: 0.5, score: 410
# Scores: (min: 15, avg: 177.02, max: 500)
#
# Run: 543, exploration: 0.5, score: 366
# Scores: (min: 15, avg: 180.21, max: 500)
#
# Run: 544, exploration: 0.5, score: 107
# Scores: (min: 15, avg: 180.8, max: 500)
#
# Run: 545, exploration: 0.5, score: 149
# Scores: (min: 15, avg: 181.54, max: 500)
#
# Run: 546, exploration: 0.5, score: 16
# Scores: (min: 15, avg: 179.98, max: 500)
#
# Run: 547, exploration: 0.5, score: 263
# Scores: (min: 15, avg: 182.44, max: 500)
#
# Run: 548, exploration: 0.5, score: 117
# Scores: (min: 15, avg: 182.19, max: 500)
#
# Run: 549, exploration: 0.5, score: 500
# Scores: (min: 15, avg: 186.73, max: 500)
#
# Run: 550, exploration: 0.5, score: 32
# Scores: (min: 15, avg: 186.37, max: 500)
#
# Run: 551, exploration: 0.5, score: 179
# Scores: (min: 15, avg: 186.14, max: 500)
#
# Run: 552, exploration: 0.5, score: 65
# Scores: (min: 15, avg: 185.45, max: 500)
#
# Run: 553, exploration: 0.5, score: 68
# Scores: (min: 15, avg: 183.14, max: 500)
#
# Run: 554, exploration: 0.5, score: 142
# Scores: (min: 15, avg: 181.93, max: 500)
#
# Run: 555, exploration: 0.5, score: 86
# Scores: (min: 15, avg: 180.45, max: 500)
#
# Run: 556, exploration: 0.5, score: 277
# Scores: (min: 15, avg: 178.22, max: 500)
#
# Run: 557, exploration: 0.5, score: 212
# Scores: (min: 16, avg: 180.19, max: 500)
#
# Run: 558, exploration: 0.5, score: 203
# Scores: (min: 16, avg: 179.14, max: 500)
#
# Run: 559, exploration: 0.5, score: 163
# Scores: (min: 16, avg: 179.7, max: 500)
#
# Run: 560, exploration: 0.5, score: 93
# Scores: (min: 16, avg: 179.74, max: 500)
#
# Run: 561, exploration: 0.5, score: 63
# Scores: (min: 16, avg: 180.01, max: 500)
#
# Run: 562, exploration: 0.5, score: 91
# Scores: (min: 16, avg: 180.54, max: 500)
#
# Run: 563, exploration: 0.5, score: 37
# Scores: (min: 16, avg: 180.52, max: 500)
#
# Run: 564, exploration: 0.5, score: 117
# Scores: (min: 16, avg: 180.58, max: 500)
#
# Run: 565, exploration: 0.5, score: 28
# Scores: (min: 16, avg: 179.9, max: 500)
#
# Run: 566, exploration: 0.5, score: 52
# Scores: (min: 16, avg: 179.1, max: 500)
#
# Run: 567, exploration: 0.5, score: 175
# Scores: (min: 16, avg: 178.13, max: 500)
#
# Run: 568, exploration: 0.5, score: 153
# Scores: (min: 16, avg: 179.34, max: 500)
#
# Run: 569, exploration: 0.5, score: 81
# Scores: (min: 16, avg: 178.78, max: 500)
#
# Run: 570, exploration: 0.5, score: 237
# Scores: (min: 16, avg: 178.55, max: 500)
#
# Run: 571, exploration: 0.5, score: 45
# Scores: (min: 16, avg: 178.61, max: 500)
#
# Run: 572, exploration: 0.5, score: 242
# Scores: (min: 16, avg: 180.72, max: 500)
#
# Run: 573, exploration: 0.5, score: 227
# Scores: (min: 16, avg: 180.5, max: 500)
#
# Run: 574, exploration: 0.5, score: 189
# Scores: (min: 16, avg: 181.5, max: 500)
#
# Run: 575, exploration: 0.5, score: 267
# Scores: (min: 16, avg: 183.14, max: 500)
#
# Run: 576, exploration: 0.5, score: 65
# Scores: (min: 16, avg: 182.55, max: 500)
#
# Run: 577, exploration: 0.5, score: 232
# Scores: (min: 16, avg: 180.99, max: 500)
#
# Run: 578, exploration: 0.5, score: 228
# Scores: (min: 16, avg: 182.54, max: 500)
#
# Run: 579, exploration: 0.5, score: 273
# Scores: (min: 16, avg: 182.57, max: 500)
#
# Run: 580, exploration: 0.5, score: 247
# Scores: (min: 16, avg: 181.41, max: 500)
#
# Run: 581, exploration: 0.5, score: 112
# Scores: (min: 16, avg: 181.82, max: 500)
#
# Run: 582, exploration: 0.5, score: 248
# Scores: (min: 16, avg: 181.39, max: 500)
#
# Run: 583, exploration: 0.5, score: 201
# Scores: (min: 16, avg: 181.48, max: 500)
#
# Run: 584, exploration: 0.5, score: 68
# Scores: (min: 16, avg: 180.76, max: 500)
#
# Run: 585, exploration: 0.5, score: 196
# Scores: (min: 16, avg: 182, max: 500)
#
# Run: 586, exploration: 0.5, score: 117
# Scores: (min: 16, avg: 179.72, max: 500)
#
# ...
#
# Run: 709, exploration: 0.5, score: 59
# Scores: (min: 9, avg: 181.11, max: 500)
#
# Run: 710, exploration: 0.5, score: 500
# Scores: (min: 9, avg: 182.75, max: 500)
#
# Run: 711, exploration: 0.5, score: 92
# Scores: (min: 9, avg: 182.4, max: 500)
#
# Run: 712, exploration: 0.5, score: 34
# Scores: (min: 9, avg: 179.74, max: 500)
#
# Run: 713, exploration: 0.5, score: 49
# Scores: (min: 9, avg: 175.68, max: 500)
#
# Run: 714, exploration: 0.5, score: 296
# Scores: (min: 9, avg: 174.1, max: 500)
#
# Run: 715, exploration: 0.5, score: 59
# Scores: (min: 9, avg: 173.65, max: 500)
#
# Run: 716, exploration: 0.5, score: 447
# Scores: (min: 9, avg: 177.21, max: 500)
#
# Run: 717, exploration: 0.5, score: 60
# Scores: (min: 9, avg: 176.95, max: 500)
#
# Run: 718, exploration: 0.5, score: 331
# Scores: (min: 9, avg: 178.18, max: 500)
#
# Run: 719, exploration: 0.5, score: 18
# Scores: (min: 9, avg: 177.56, max: 500)
#
# Run: 720, exploration: 0.5, score: 32
# Scores: (min: 9, avg: 177.45, max: 500)
#
# Run: 721, exploration: 0.5, score: 11
# Scores: (min: 9, avg: 172.56, max: 500)
#
# Run: 722, exploration: 0.5, score: 171
# Scores: (min: 9, avg: 172.43, max: 500)
#
# Run: 723, exploration: 0.5, score: 33
# Scores: (min: 9, avg: 172.06, max: 500)
#
# Run: 724, exploration: 0.5, score: 67
# Scores: (min: 9, avg: 171.21, max: 500)
#
# Run: 725, exploration: 0.5, score: 192
# Scores: (min: 9, avg: 172.73, max: 500)
#
# Run: 726, exploration: 0.5, score: 122
# Scores: (min: 9, avg: 172.16, max: 500)
#
# Run: 727, exploration: 0.5, score: 87
# Scores: (min: 9, avg: 172.19, max: 500)
#
# Run: 728, exploration: 0.5, score: 257
# Scores: (min: 9, avg: 170.54, max: 500)
#
# Run: 729, exploration: 0.5, score: 143
# Scores: (min: 9, avg: 171.19, max: 500)
#
# Run: 730, exploration: 0.5, score: 271
# Scores: (min: 9, avg: 172.36, max: 500)
#
# Run: 731, exploration: 0.5, score: 20
# Scores: (min: 9, avg: 169.72, max: 500)
#
# Run: 732, exploration: 0.5, score: 86
# Scores: (min: 9, avg: 168.77, max: 500)
#
# Run: 733, exploration: 0.5, score: 119
# Scores: (min: 9, avg: 169.8, max: 500)
#
# Run: 734, exploration: 0.5, score: 31
# Scores: (min: 9, avg: 167.99, max: 500)
#
# Run: 735, exploration: 0.5, score: 334
# Scores: (min: 9, avg: 171.05, max: 500)
#
# Run: 736, exploration: 0.5, score: 500
# Scores: (min: 9, avg: 174.2, max: 500)
#
# Run: 737, exploration: 0.5, score: 232
# Scores: (min: 9, avg: 175.83, max: 500)
#
# Run: 738, exploration: 0.5, score: 140
# Scores: (min: 9, avg: 174.71, max: 500)
#
# Run: 739, exploration: 0.5, score: 500
# Scores: (min: 9, avg: 179.42, max: 500)
#
# Run: 740, exploration: 0.5, score: 191
# Scores: (min: 9, avg: 180.72, max: 500)
#
# Run: 741, exploration: 0.5, score: 41
# Scores: (min: 9, avg: 177.92, max: 500)
#
# Run: 742, exploration: 0.5, score: 500
# Scores: (min: 9, avg: 182.04, max: 500)
#
# Run: 743, exploration: 0.5, score: 139
# Scores: (min: 9, avg: 182.26, max: 500)
#
# Run: 744, exploration: 0.5, score: 14
# Scores: (min: 9, avg: 180.97, max: 500)
#
# Run: 745, exploration: 0.5, score: 56
# Scores: (min: 9, avg: 178.61, max: 500)
#
# Run: 746, exploration: 0.5, score: 244
# Scores: (min: 9, avg: 176.33, max: 500)
#
# Run: 747, exploration: 0.5, score: 281
# Scores: (min: 9, avg: 176.79, max: 500)
#
# Run: 748, exploration: 0.5, score: 93
# Scores: (min: 11, avg: 177.63, max: 500)
#
# Run: 749, exploration: 0.5, score: 422
# Scores: (min: 11, avg: 181.54, max: 500)
#
# Run: 750, exploration: 0.5, score: 155
# Scores: (min: 11, avg: 182.29, max: 500)
#
# Run: 751, exploration: 0.5, score: 35
# Scores: (min: 11, avg: 179.91, max: 500)
#
# Run: 752, exploration: 0.5, score: 157
# Scores: (min: 11, avg: 181.07, max: 500)
#
# Run: 753, exploration: 0.5, score: 57
# Scores: (min: 11, avg: 178.89, max: 500)
#
# Run: 754, exploration: 0.5, score: 313
# Scores: (min: 11, avg: 180.75, max: 500)
#
# Run: 755, exploration: 0.5, score: 109
# Scores: (min: 11, avg: 176.84, max: 500)
#
# Run: 756, exploration: 0.5, score: 78
# Scores: (min: 11, avg: 174.7, max: 500)
#
# Run: 757, exploration: 0.5, score: 148
# Scores: (min: 11, avg: 175.72, max: 500)
#
# Run: 758, exploration: 0.5, score: 278
# Scores: (min: 11, avg: 177.81, max: 500)
#
# Run: 759, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 182.27, max: 500)
#
# Run: 760, exploration: 0.5, score: 39
# Scores: (min: 11, avg: 180.03, max: 500)
#
# Run: 761, exploration: 0.5, score: 13
# Scores: (min: 11, avg: 178.87, max: 500)
#
# Run: 762, exploration: 0.5, score: 296
# Scores: (min: 11, avg: 181.12, max: 500)
#
# Run: 763, exploration: 0.5, score: 166
# Scores: (min: 11, avg: 181.15, max: 500)
#
# Run: 764, exploration: 0.5, score: 89
# Scores: (min: 11, avg: 181.19, max: 500)
#
# Run: 765, exploration: 0.5, score: 17
# Scores: (min: 11, avg: 178.57, max: 500)
#
# Run: 766, exploration: 0.5, score: 49
# Scores: (min: 11, avg: 177.6, max: 500)
#
# Run: 767, exploration: 0.5, score: 174
# Scores: (min: 11, avg: 178.85, max: 500)
#
# Run: 768, exploration: 0.5, score: 42
# Scores: (min: 11, avg: 178.35, max: 500)
#
# Run: 769, exploration: 0.5, score: 60
# Scores: (min: 11, avg: 178.25, max: 500)
#
# Run: 770, exploration: 0.5, score: 220
# Scores: (min: 11, avg: 179.46, max: 500)
#
# Run: 771, exploration: 0.5, score: 27
# Scores: (min: 11, avg: 178.07, max: 500)
#
# Run: 772, exploration: 0.5, score: 136
# Scores: (min: 11, avg: 177.74, max: 500)
#
# Run: 773, exploration: 0.5, score: 287
# Scores: (min: 11, avg: 176.18, max: 500)
#
# Run: 774, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 180.23, max: 500)
#
# Run: 775, exploration: 0.5, score: 203
# Scores: (min: 11, avg: 177.85, max: 500)
#
# Run: 776, exploration: 0.5, score: 280
# Scores: (min: 11, avg: 180.42, max: 500)
#
# Run: 777, exploration: 0.5, score: 13
# Scores: (min: 11, avg: 178.44, max: 500)
#
# Run: 778, exploration: 0.5, score: 88
# Scores: (min: 11, avg: 177.68, max: 500)
#
# Run: 779, exploration: 0.5, score: 92
# Scores: (min: 11, avg: 178.3, max: 500)
#
# Run: 780, exploration: 0.5, score: 127
# Scores: (min: 11, avg: 176.61, max: 500)
#
# Run: 781, exploration: 0.5, score: 26
# Scores: (min: 11, avg: 172.92, max: 500)
#
# Run: 782, exploration: 0.5, score: 139
# Scores: (min: 11, avg: 173.38, max: 500)
#
# Run: 783, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 176.22, max: 500)
#
# Run: 784, exploration: 0.5, score: 68
# Scores: (min: 11, avg: 175.75, max: 500)
#
# Run: 785, exploration: 0.5, score: 315
# Scores: (min: 11, avg: 177.88, max: 500)
#
# Run: 786, exploration: 0.5, score: 83
# Scores: (min: 11, avg: 176.93, max: 500)
#
# Run: 787, exploration: 0.5, score: 386
# Scores: (min: 11, avg: 179.88, max: 500)
#
# Run: 788, exploration: 0.5, score: 266
# Scores: (min: 11, avg: 181.39, max: 500)
#
# Run: 789, exploration: 0.5, score: 25
# Scores: (min: 11, avg: 180.56, max: 500)
#
# Run: 790, exploration: 0.5, score: 125
# Scores: (min: 11, avg: 179.05, max: 500)
#
# Run: 791, exploration: 0.5, score: 31
# Scores: (min: 11, avg: 174.36, max: 500)
#
# Run: 792, exploration: 0.5, score: 374
# Scores: (min: 11, avg: 177.23, max: 500)
#
# Run: 793, exploration: 0.5, score: 303
# Scores: (min: 11, avg: 179.21, max: 500)
#
# Run: 794, exploration: 0.5, score: 96
# Scores: (min: 11, avg: 178.88, max: 500)
#
# Run: 795, exploration: 0.5, score: 210
# Scores: (min: 11, avg: 179.45, max: 500)
#
# Run: 796, exploration: 0.5, score: 280
# Scores: (min: 11, avg: 178.8, max: 500)
#
# Run: 797, exploration: 0.5, score: 17
# Scores: (min: 11, avg: 177.19, max: 500)
#
# Run: 798, exploration: 0.5, score: 54
# Scores: (min: 11, avg: 173.08, max: 500)
#
# Run: 799, exploration: 0.5, score: 191
# Scores: (min: 11, avg: 174.15, max: 500)
#
# Run: 800, exploration: 0.5, score: 77
# Scores: (min: 11, avg: 174.17, max: 500)
#
# Run: 801, exploration: 0.5, score: 371
# Scores: (min: 11, avg: 176.63, max: 500)
#
# Run: 802, exploration: 0.5, score: 167
# Scores: (min: 11, avg: 176.97, max: 500)
#
# Run: 803, exploration: 0.5, score: 356
# Scores: (min: 11, avg: 176.45, max: 500)
#
# Run: 804, exploration: 0.5, score: 94
# Scores: (min: 11, avg: 175.42, max: 500)
#
# Run: 805, exploration: 0.5, score: 212
# Scores: (min: 11, avg: 173.15, max: 500)
#
# Run: 806, exploration: 0.5, score: 395
# Scores: (min: 11, avg: 176.01, max: 500)
#
# Run: 807, exploration: 0.5, score: 146
# Scores: (min: 11, avg: 176.96, max: 500)
#
# Run: 808, exploration: 0.5, score: 198
# Scores: (min: 11, avg: 175.27, max: 500)
# Run: 809, exploration: 0.5, score: 33
# Scores: (min: 11, avg: 175.01, max: 500)
#
# Run: 810, exploration: 0.5, score: 29
# Scores: (min: 11, avg: 170.3, max: 500)
#
# Run: 811, exploration: 0.5, score: 59
# Scores: (min: 11, avg: 169.97, max: 500)
#
# Run: 812, exploration: 0.5, score: 56
# Scores: (min: 11, avg: 170.19, max: 500)
#
# Run: 813, exploration: 0.5, score: 74
# Scores: (min: 11, avg: 170.44, max: 500)
#
# Run: 814, exploration: 0.5, score: 291
# Scores: (min: 11, avg: 170.39, max: 500)
#
# Run: 815, exploration: 0.5, score: 23
# Scores: (min: 11, avg: 170.03, max: 500)
#
# Run: 816, exploration: 0.5, score: 327
# Scores: (min: 11, avg: 168.83, max: 500)
#
# Run: 817, exploration: 0.5, score: 187
# Scores: (min: 11, avg: 170.1, max: 500)
#
# Run: 818, exploration: 0.5, score: 192
# Scores: (min: 11, avg: 168.71, max: 500)
#
# Run: 819, exploration: 0.5, score: 135
# Scores: (min: 11, avg: 169.88, max: 500)
#
# Run: 820, exploration: 0.5, score: 45
# Scores: (min: 11, avg: 170.01, max: 500)
#
# Run: 821, exploration: 0.5, score: 257
# Scores: (min: 13, avg: 172.47, max: 500)
#
# Run: 822, exploration: 0.5, score: 43
# Scores: (min: 13, avg: 171.19, max: 500)
#
# Run: 823, exploration: 0.5, score: 220
# Scores: (min: 13, avg: 173.06, max: 500)
#
# Run: 824, exploration: 0.5, score: 62
# Scores: (min: 13, avg: 173.01, max: 500)
#
# Run: 825, exploration: 0.5, score: 180
# Scores: (min: 13, avg: 172.89, max: 500)
#
# Run: 826, exploration: 0.5, score: 315
# Scores: (min: 13, avg: 174.82, max: 500)
#
# Run: 827, exploration: 0.5, score: 191
# Scores: (min: 13, avg: 175.86, max: 500)
#
# Run: 828, exploration: 0.5, score: 221
# Scores: (min: 13, avg: 175.5, max: 500)
#
# Run: 829, exploration: 0.5, score: 142
# Scores: (min: 13, avg: 175.49, max: 500)
#
# Run: 830, exploration: 0.5, score: 500
# Scores: (min: 13, avg: 177.78, max: 500)
#
# Run: 831, exploration: 0.5, score: 127
# Scores: (min: 13, avg: 178.85, max: 500)
#
# Run: 832, exploration: 0.5, score: 79
# Scores: (min: 13, avg: 178.78, max: 500)
#
# Run: 833, exploration: 0.5, score: 91
# Scores: (min: 13, avg: 178.5, max: 500)
#
# Run: 834, exploration: 0.5, score: 46
# Scores: (min: 13, avg: 178.65, max: 500)
#
# Run: 835, exploration: 0.5, score: 250
# Scores: (min: 13, avg: 177.81, max: 500)
#
# Run: 836, exploration: 0.5, score: 161
# Scores: (min: 13, avg: 174.42, max: 500)
#
# Run: 837, exploration: 0.5, score: 331
# Scores: (min: 13, avg: 175.41, max: 500)
#
# Run: 838, exploration: 0.5, score: 85
# Scores: (min: 13, avg: 174.86, max: 500)
#
# Run: 839, exploration: 0.5, score: 151
# Scores: (min: 13, avg: 171.37, max: 500)
#
# Run: 840, exploration: 0.5, score: 449
# Scores: (min: 13, avg: 173.95, max: 500)
#
# Run: 841, exploration: 0.5, score: 416
# Scores: (min: 13, avg: 177.7, max: 500)
#
# Run: 842, exploration: 0.5, score: 291
# Scores: (min: 13, avg: 175.61, max: 500)
#
# Run: 843, exploration: 0.5, score: 500
# Scores: (min: 13, avg: 179.22, max: 500)
#
# Run: 844, exploration: 0.5, score: 65
# Scores: (min: 13, avg: 179.73, max: 500)
#
# Run: 845, exploration: 0.5, score: 147
# Scores: (min: 13, avg: 180.64, max: 500)
#
# Run: 846, exploration: 0.5, score: 17
# Scores: (min: 13, avg: 178.37, max: 500)
#
# Run: 847, exploration: 0.5, score: 141
# Scores: (min: 13, avg: 176.97, max: 500)
#
# Run: 848, exploration: 0.5, score: 431
# Scores: (min: 13, avg: 180.35, max: 500)
#
# Run: 849, exploration: 0.5, score: 93
# Scores: (min: 13, avg: 177.06, max: 500)
#
# Run: 850, exploration: 0.5, score: 75
# Scores: (min: 13, avg: 176.26, max: 500)
#
# Run: 851, exploration: 0.5, score: 455
# Scores: (min: 13, avg: 180.46, max: 500)
#
# Run: 852, exploration: 0.5, score: 330
# Scores: (min: 13, avg: 182.19, max: 500)
#
# Run: 853, exploration: 0.5, score: 318
# Scores: (min: 13, avg: 184.8, max: 500)
#
# Run: 854, exploration: 0.5, score: 131
# Scores: (min: 13, avg: 182.98, max: 500)
#
# Run: 855, exploration: 0.5, score: 431
# Scores: (min: 13, avg: 186.2, max: 500)
#
# Run: 856, exploration: 0.5, score: 144
# Scores: (min: 13, avg: 186.86, max: 500)
#
# Run: 857, exploration: 0.5, score: 108
# Scores: (min: 13, avg: 186.46, max: 500)
#
# Run: 858, exploration: 0.5, score: 53
# Scores: (min: 13, avg: 184.21, max: 500)
#
# Run: 859, exploration: 0.5, score: 112
# Scores: (min: 13, avg: 180.33, max: 500)
#
# Run: 860, exploration: 0.5, score: 342
# Scores: (min: 13, avg: 183.36, max: 500)
#
# Run: 861, exploration: 0.5, score: 73
# Scores: (min: 13, avg: 183.96, max: 500)
#
# Run: 862, exploration: 0.5, score: 161
# Scores: (min: 13, avg: 182.61, max: 500)
#
# Run: 863, exploration: 0.5, score: 41
# Scores: (min: 13, avg: 181.36, max: 500)
#
# Run: 864, exploration: 0.5, score: 124
# Scores: (min: 13, avg: 181.71, max: 500)
#
# Run: 865, exploration: 0.5, score: 52
# Scores: (min: 13, avg: 182.06, max: 500)
#
# Run: 866, exploration: 0.5, score: 473
# Scores: (min: 13, avg: 186.3, max: 500)
#
# Run: 867, exploration: 0.5, score: 136
# Scores: (min: 13, avg: 185.92, max: 500)
#
# Run: 868, exploration: 0.5, score: 68
# Scores: (min: 13, avg: 186.18, max: 500)
#
# Run: 869, exploration: 0.5, score: 393
# Scores: (min: 13, avg: 189.51, max: 500)
#
# Run: 870, exploration: 0.5, score: 317
# Scores: (min: 13, avg: 190.48, max: 500)
#
# Run: 871, exploration: 0.5, score: 152
# Scores: (min: 13, avg: 191.73, max: 500)
#
# Run: 872, exploration: 0.5, score: 174
# Scores: (min: 13, avg: 192.11, max: 500)
#
# Run: 873, exploration: 0.5, score: 169
# Scores: (min: 13, avg: 190.93, max: 500)
#
# Run: 874, exploration: 0.5, score: 213
# Scores: (min: 13, avg: 188.06, max: 500)
#
# Run: 875, exploration: 0.5, score: 221
# Scores: (min: 13, avg: 188.24, max: 500)
#
# Run: 876, exploration: 0.5, score: 94
# Scores: (min: 13, avg: 186.38, max: 500)
#
# Run: 877, exploration: 0.5, score: 313
# Scores: (min: 17, avg: 189.38, max: 500)
#
# Run: 878, exploration: 0.5, score: 90
# Scores: (min: 17, avg: 189.4, max: 500)
#
# Run: 879, exploration: 0.5, score: 49
# Scores: (min: 17, avg: 188.97, max: 500)
#
# Run: 880, exploration: 0.5, score: 63
# Scores: (min: 17, avg: 188.33, max: 500)
#
# Run: 881, exploration: 0.5, score: 163
# Scores: (min: 17, avg: 189.7, max: 500)
#
# Run: 882, exploration: 0.5, score: 39
# Scores: (min: 17, avg: 188.7, max: 500)
#
# Run: 883, exploration: 0.5, score: 120
# Scores: (min: 17, avg: 184.9, max: 500)
#
# Run: 884, exploration: 0.5, score: 205
# Scores: (min: 17, avg: 186.27, max: 500)
#
# Run: 885, exploration: 0.5, score: 426
# Scores: (min: 17, avg: 187.38, max: 500)
#
# Run: 886, exploration: 0.5, score: 111
# Scores: (min: 17, avg: 187.66, max: 500)
#
# Run: 887, exploration: 0.5, score: 500
# Scores: (min: 17, avg: 188.8, max: 500)
#
# Run: 888, exploration: 0.5, score: 18
# Scores: (min: 17, avg: 186.32, max: 500)
#
# Run: 889, exploration: 0.5, score: 362
# Scores: (min: 17, avg: 189.69, max: 500)
#
# Run: 890, exploration: 0.5, score: 255
# Scores: (min: 17, avg: 190.99, max: 500)
#
# Run: 891, exploration: 0.5, score: 240
# Scores: (min: 17, avg: 193.08, max: 500)
#
# Run: 892, exploration: 0.5, score: 279
# Scores: (min: 17, avg: 192.13, max: 500)
#
# Run: 893, exploration: 0.5, score: 410
# Scores: (min: 17, avg: 193.2, max: 500)
#
# Run: 894, exploration: 0.5, score: 261
# Scores: (min: 17, avg: 194.85, max: 500)
#
# Run: 895, exploration: 0.5, score: 294
# Scores: (min: 17, avg: 195.69, max: 500)
#
# Solved in 795 runs, 895 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-10-01869693585d> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
from scores.score_logger import ScoreLogger

# Modified cartpole: increased gamma to 0.995, increased exploration min to 0.5, increased learning rate to 0.01

ENV_NAME = "CartPole-v1"

GAMMA = 0.995
LEARNING_RATE = 0.01

MEMORY_SIZE = 1000000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.5
EXPLORATION_DECAY = 0.995


class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)


def cartpole():
    env = gym.make(ENV_NAME)
    score_logger = ScoreLogger(ENV_NAME)
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            #env.render()
            action = dqn_solver.act(state)
            state_next, reward, terminal, info = env.step(action)
            reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
                score_logger.add_score(step, run)
                break
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9801495006250001, score: 24
# Scores: (min: 24, avg: 24, max: 24)
#
# Run: 2, exploration: 0.8866535105013078, score: 21
# Scores: (min: 21, avg: 22.5, max: 24)
#
# Run: 3, exploration: 0.8020760579717637, score: 21
# Scores: (min: 21, avg: 22, max: 24)
#
# Run: 4, exploration: 0.736559652908221, score: 18
# Scores: (min: 18, avg: 21, max: 24)
#
# Run: 5, exploration: 0.697046600835495, score: 12
# Scores: (min: 12, avg: 19.2, max: 24)
#
# Run: 6, exploration: 0.6057704364907278, score: 29
# Scores: (min: 12, avg: 20.833333333333332, max: 29)
#
# Run: 7, exploration: 0.5238143793828016, score: 30
# Scores: (min: 12, avg: 22.142857142857142, max: 30)
#
# Run: 8, exploration: 0.5, score: 11
# Scores: (min: 11, avg: 20.75, max: 30)
#
# Run: 9, exploration: 0.5, score: 11
# Scores: (min: 11, avg: 19.666666666666668, max: 30)
#
# Run: 10, exploration: 0.5, score: 10
# Scores: (min: 10, avg: 18.7, max: 30)
#
# Run: 11, exploration: 0.5, score: 10
# Scores: (min: 10, avg: 17.90909090909091, max: 30)
#
# Run: 12, exploration: 0.5, score: 10
# Scores: (min: 10, avg: 17.25, max: 30)
#
# Run: 13, exploration: 0.5, score: 9
# Scores: (min: 9, avg: 16.615384615384617, max: 30)
#
# Run: 14, exploration: 0.5, score: 47
# Scores: (min: 9, avg: 18.785714285714285, max: 47)
#
# Run: 15, exploration: 0.5, score: 12
# Scores: (min: 9, avg: 18.333333333333332, max: 47)
#
# Run: 16, exploration: 0.5, score: 10
# Scores: (min: 9, avg: 17.8125, max: 47)
#
# Run: 17, exploration: 0.5, score: 11
# Scores: (min: 9, avg: 17.41176470588235, max: 47)
#
# Run: 18, exploration: 0.5, score: 9
# Scores: (min: 9, avg: 16.944444444444443, max: 47)
#
# Run: 19, exploration: 0.5, score: 16
# Scores: (min: 9, avg: 16.894736842105264, max: 47)
#
# Run: 20, exploration: 0.5, score: 20
# Scores: (min: 9, avg: 17.05, max: 47)
#
# Run: 21, exploration: 0.5, score: 38
# Scores: (min: 9, avg: 18.047619047619047, max: 47)
#
# Run: 22, exploration: 0.5, score: 15
# Scores: (min: 9, avg: 17.90909090909091, max: 47)
#
# Run: 23, exploration: 0.5, score: 13
# Scores: (min: 9, avg: 17.695652173913043, max: 47)
#
# Run: 24, exploration: 0.5, score: 21
# Scores: (min: 9, avg: 17.833333333333332, max: 47)
#
# Run: 25, exploration: 0.5, score: 15
# Scores: (min: 9, avg: 17.72, max: 47)
#
# Run: 26, exploration: 0.5, score: 17
# Scores: (min: 9, avg: 17.692307692307693, max: 47)
#
# Run: 27, exploration: 0.5, score: 13
# Scores: (min: 9, avg: 17.51851851851852, max: 47)
#
# Run: 28, exploration: 0.5, score: 13
# Scores: (min: 9, avg: 17.357142857142858, max: 47)
#
# Run: 29, exploration: 0.5, score: 14
# Scores: (min: 9, avg: 17.24137931034483, max: 47)
#
# Run: 30, exploration: 0.5, score: 22
# Scores: (min: 9, avg: 17.4, max: 47)
#
# Run: 31, exploration: 0.5, score: 10
# Scores: (min: 9, avg: 17.161290322580644, max: 47)
#
# Run: 32, exploration: 0.5, score: 10
# Scores: (min: 9, avg: 16.9375, max: 47)
#
# Run: 33, exploration: 0.5, score: 9
# Scores: (min: 9, avg: 16.696969696969695, max: 47)
#
# Run: 34, exploration: 0.5, score: 14
# Scores: (min: 9, avg: 16.61764705882353, max: 47)
#
# Run: 35, exploration: 0.5, score: 16
# Scores: (min: 9, avg: 16.6, max: 47)
#
# Run: 36, exploration: 0.5, score: 14
# Scores: (min: 9, avg: 16.52777777777778, max: 47)
#
# Run: 37, exploration: 0.5, score: 9
# Scores: (min: 9, avg: 16.324324324324323, max: 47)
#
# Run: 38, exploration: 0.5, score: 8
# Scores: (min: 8, avg: 16.105263157894736, max: 47)
#
# Run: 39, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 15.974358974358974, max: 47)
#
# Run: 40, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 15.85, max: 47)
#
# Run: 41, exploration: 0.5, score: 9
# Scores: (min: 8, avg: 15.682926829268293, max: 47)
#
# Run: 42, exploration: 0.5, score: 9
# Scores: (min: 8, avg: 15.523809523809524, max: 47)
#
# Run: 43, exploration: 0.5, score: 15
# Scores: (min: 8, avg: 15.511627906976743, max: 47)
#
# Run: 44, exploration: 0.5, score: 35
# Scores: (min: 8, avg: 15.954545454545455, max: 47)
#
# Run: 45, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 15.866666666666667, max: 47)
#
# Run: 46, exploration: 0.5, score: 14
# Scores: (min: 8, avg: 15.826086956521738, max: 47)
#
# Run: 47, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 15.72340425531915, max: 47)
#
# Run: 48, exploration: 0.5, score: 9
# Scores: (min: 8, avg: 15.583333333333334, max: 47)
#
# Run: 49, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 15.489795918367347, max: 47)
#
# Run: 50, exploration: 0.5, score: 13
# Scores: (min: 8, avg: 15.44, max: 47)
#
# Run: 51, exploration: 0.5, score: 9
# Scores: (min: 8, avg: 15.313725490196079, max: 47)
#
# Run: 52, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 15.25, max: 47)
#
# Run: 53, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 15.18867924528302, max: 47)
#
# Run: 54, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 15.12962962962963, max: 47)
#
# Run: 55, exploration: 0.5, score: 9
# Scores: (min: 8, avg: 15.018181818181818, max: 47)
#
# Run: 56, exploration: 0.5, score: 15
# Scores: (min: 8, avg: 15.017857142857142, max: 47)
#
# Run: 57, exploration: 0.5, score: 18
# Scores: (min: 8, avg: 15.070175438596491, max: 47)
#
# Run: 58, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 15, max: 47)
#
# Run: 59, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.932203389830509, max: 47)
#
# Run: 60, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.866666666666667, max: 47)
#
# Run: 61, exploration: 0.5, score: 16
# Scores: (min: 8, avg: 14.885245901639344, max: 47)
#
# Run: 62, exploration: 0.5, score: 16
# Scores: (min: 8, avg: 14.903225806451612, max: 47)
#
# Run: 63, exploration: 0.5, score: 14
# Scores: (min: 8, avg: 14.88888888888889, max: 47)
#
# Run: 64, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 14.84375, max: 47)
#
# Run: 65, exploration: 0.5, score: 13
# Scores: (min: 8, avg: 14.815384615384616, max: 47)
#
# Run: 66, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.757575757575758, max: 47)
#
# Run: 67, exploration: 0.5, score: 16
# Scores: (min: 8, avg: 14.776119402985074, max: 47)
#
# Run: 68, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.720588235294118, max: 47)
#
# Run: 69, exploration: 0.5, score: 14
# Scores: (min: 8, avg: 14.710144927536232, max: 47)
#
# Run: 70, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 14.67142857142857, max: 47)
#
# Run: 71, exploration: 0.5, score: 10
# Scores: (min: 8, avg: 14.605633802816902, max: 47)
#
# Run: 72, exploration: 0.5, score: 10
# Scores: (min: 8, avg: 14.541666666666666, max: 47)
#
# Run: 73, exploration: 0.5, score: 17
# Scores: (min: 8, avg: 14.575342465753424, max: 47)
#
# Run: 74, exploration: 0.5, score: 17
# Scores: (min: 8, avg: 14.608108108108109, max: 47)
#
# Run: 75, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 14.573333333333334, max: 47)
#
# Run: 76, exploration: 0.5, score: 27
# Scores: (min: 8, avg: 14.736842105263158, max: 47)
#
# Run: 77, exploration: 0.5, score: 9
# Scores: (min: 8, avg: 14.662337662337663, max: 47)
#
# Run: 78, exploration: 0.5, score: 16
# Scores: (min: 8, avg: 14.679487179487179, max: 47)
#
# Run: 79, exploration: 0.5, score: 10
# Scores: (min: 8, avg: 14.620253164556962, max: 47)
#
# Run: 80, exploration: 0.5, score: 13
# Scores: (min: 8, avg: 14.6, max: 47)
#
# Run: 81, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.555555555555555, max: 47)
#
# Run: 82, exploration: 0.5, score: 10
# Scores: (min: 8, avg: 14.5, max: 47)
#
# Run: 83, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.457831325301205, max: 47)
#
# Run: 84, exploration: 0.5, score: 18
# Scores: (min: 8, avg: 14.5, max: 47)
#
# Run: 85, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.458823529411765, max: 47)
#
# Run: 86, exploration: 0.5, score: 25
# Scores: (min: 8, avg: 14.581395348837209, max: 47)
#
# Run: 87, exploration: 0.5, score: 16
# Scores: (min: 8, avg: 14.597701149425287, max: 47)
#
# Run: 88, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 14.568181818181818, max: 47)
#
# Run: 89, exploration: 0.5, score: 10
# Scores: (min: 8, avg: 14.51685393258427, max: 47)
#
# Run: 90, exploration: 0.5, score: 10
# Scores: (min: 8, avg: 14.466666666666667, max: 47)
#
# Run: 91, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.428571428571429, max: 47)
#
# Run: 92, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.391304347826088, max: 47)
#
# Run: 93, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.35483870967742, max: 47)
#
# Run: 94, exploration: 0.5, score: 17
# Scores: (min: 8, avg: 14.382978723404255, max: 47)
#
# Run: 95, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.347368421052632, max: 47)
# Run: 96, exploration: 0.5, score: 27
# Scores: (min: 8, avg: 14.479166666666666, max: 47)
#
# Run: 97, exploration: 0.5, score: 21
# Scores: (min: 8, avg: 14.54639175257732, max: 47)
#
# Run: 98, exploration: 0.5, score: 24
# Scores: (min: 8, avg: 14.642857142857142, max: 47)
#
# Run: 99, exploration: 0.5, score: 27
# Scores: (min: 8, avg: 14.767676767676768, max: 47)
#
# Run: 100, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.73, max: 47)
#
# Run: 101, exploration: 0.5, score: 9
# Scores: (min: 8, avg: 14.58, max: 47)
#
# Run: 102, exploration: 0.5, score: 27
# Scores: (min: 8, avg: 14.64, max: 47)
#
# Run: 103, exploration: 0.5, score: 19
# Scores: (min: 8, avg: 14.62, max: 47)
#
# Run: 104, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 14.56, max: 47)
#
# Run: 105, exploration: 0.5, score: 13
# Scores: (min: 8, avg: 14.57, max: 47)
#
# Run: 106, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.39, max: 47)
#
# Run: 107, exploration: 0.5, score: 14
# Scores: (min: 8, avg: 14.23, max: 47)
#
# Run: 108, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.23, max: 47)
#
# Run: 109, exploration: 0.5, score: 10
# Scores: (min: 8, avg: 14.22, max: 47)
#
# Run: 110, exploration: 0.5, score: 13
# Scores: (min: 8, avg: 14.25, max: 47)
#
# Run: 111, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.26, max: 47)
#
# Run: 112, exploration: 0.5, score: 20
# Scores: (min: 8, avg: 14.36, max: 47)
#
# Run: 113, exploration: 0.5, score: 60
# Scores: (min: 8, avg: 14.87, max: 60)
#
# Run: 114, exploration: 0.5, score: 47
# Scores: (min: 8, avg: 14.87, max: 60)
#
# Run: 115, exploration: 0.5, score: 37
# Scores: (min: 8, avg: 15.12, max: 60)
#
# Run: 116, exploration: 0.5, score: 30
# Scores: (min: 8, avg: 15.32, max: 60)
#
# Run: 117, exploration: 0.5, score: 10
# Scores: (min: 8, avg: 15.31, max: 60)
#
# Run: 118, exploration: 0.5, score: 14
# Scores: (min: 8, avg: 15.36, max: 60)
#
# Run: 119, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 15.32, max: 60)
#
# Run: 120, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 15.24, max: 60)
#
# Run: 121, exploration: 0.5, score: 15
# Scores: (min: 8, avg: 15.01, max: 60)
#
# Run: 122, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 14.98, max: 60)
#
# Run: 123, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.96, max: 60)
#
# Run: 124, exploration: 0.5, score: 18
# Scores: (min: 8, avg: 14.93, max: 60)
#
# Run: 125, exploration: 0.5, score: 10
# Scores: (min: 8, avg: 14.88, max: 60)
#
# Run: 126, exploration: 0.5, score: 13
# Scores: (min: 8, avg: 14.84, max: 60)
#
# Run: 127, exploration: 0.5, score: 13
# Scores: (min: 8, avg: 14.84, max: 60)
#
# Run: 128, exploration: 0.5, score: 11
# Scores: (min: 8, avg: 14.82, max: 60)
#
# Run: 129, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 14.8, max: 60)
#
# Run: 130, exploration: 0.5, score: 9
# Scores: (min: 8, avg: 14.67, max: 60)
#
# Run: 131, exploration: 0.5, score: 12
# Scores: (min: 8, avg: 14.69, max: 60)
#
# Run: 132, exploration: 0.5, score: 22
# Scores: (min: 8, avg: 14.81, max: 60)
#
# Run: 133, exploration: 0.5, score: 54
# Scores: (min: 8, avg: 15.26, max: 60)
#
# Run: 134, exploration: 0.5, score: 46
# Scores: (min: 8, avg: 15.58, max: 60)
#
# Run: 135, exploration: 0.5, score: 26
# Scores: (min: 8, avg: 15.68, max: 60)
#
# Run: 136, exploration: 0.5, score: 18
# Scores: (min: 8, avg: 15.72, max: 60)
#
# Run: 137, exploration: 0.5, score: 22
# Scores: (min: 8, avg: 15.85, max: 60)
#
# Run: 138, exploration: 0.5, score: 16
# Scores: (min: 9, avg: 15.93, max: 60)
#
# Run: 139, exploration: 0.5, score: 16
# Scores: (min: 9, avg: 15.98, max: 60)
#
# Run: 140, exploration: 0.5, score: 13
# Scores: (min: 9, avg: 16, max: 60)
#
# Run: 141, exploration: 0.5, score: 20
# Scores: (min: 9, avg: 16.11, max: 60)
#
# Run: 142, exploration: 0.5, score: 22
# Scores: (min: 9, avg: 16.24, max: 60)
#
# Run: 143, exploration: 0.5, score: 21
# Scores: (min: 9, avg: 16.3, max: 60)
#
# Run: 144, exploration: 0.5, score: 17
# Scores: (min: 9, avg: 16.12, max: 60)
#
# Run: 145, exploration: 0.5, score: 24
# Scores: (min: 9, avg: 16.24, max: 60)
#
# Run: 146, exploration: 0.5, score: 27
# Scores: (min: 9, avg: 16.37, max: 60)
#
# Run: 147, exploration: 0.5, score: 27
# Scores: (min: 9, avg: 16.53, max: 60)
#
# Run: 148, exploration: 0.5, score: 16
# Scores: (min: 9, avg: 16.6, max: 60)
#
# Run: 149, exploration: 0.5, score: 43
# Scores: (min: 9, avg: 16.92, max: 60)
#
# Run: 150, exploration: 0.5, score: 21
# Scores: (min: 9, avg: 17, max: 60)
#
# Run: 151, exploration: 0.5, score: 15
# Scores: (min: 9, avg: 17.06, max: 60)
#
# Run: 152, exploration: 0.5, score: 34
# Scores: (min: 9, avg: 17.28, max: 60)
#
# Run: 153, exploration: 0.5, score: 36
# Scores: (min: 9, avg: 17.52, max: 60)
#
# Run: 154, exploration: 0.5, score: 66
# Scores: (min: 9, avg: 18.06, max: 66)
#
# Run: 155, exploration: 0.5, score: 36
# Scores: (min: 9, avg: 18.33, max: 66)
#
# Run: 156, exploration: 0.5, score: 53
# Scores: (min: 9, avg: 18.71, max: 66)
#
# Run: 157, exploration: 0.5, score: 143
# Scores: (min: 9, avg: 19.96, max: 143)
#
# Run: 158, exploration: 0.5, score: 63
# Scores: (min: 9, avg: 20.48, max: 143)
#
# Run: 159, exploration: 0.5, score: 65
# Scores: (min: 9, avg: 21.02, max: 143)
#
# Run: 160, exploration: 0.5, score: 43
# Scores: (min: 9, avg: 21.34, max: 143)
#
# Run: 161, exploration: 0.5, score: 111
# Scores: (min: 9, avg: 22.29, max: 143)
#
# Run: 162, exploration: 0.5, score: 105
# Scores: (min: 9, avg: 23.18, max: 143)
#
# Run: 163, exploration: 0.5, score: 69
# Scores: (min: 9, avg: 23.73, max: 143)
#
# Run: 164, exploration: 0.5, score: 101
# Scores: (min: 9, avg: 24.62, max: 143)
#
# Run: 165, exploration: 0.5, score: 63
# Scores: (min: 9, avg: 25.12, max: 143)
#
# Run: 166, exploration: 0.5, score: 87
# Scores: (min: 9, avg: 25.88, max: 143)
#
# Run: 167, exploration: 0.5, score: 18
# Scores: (min: 9, avg: 25.9, max: 143)
#
# Run: 168, exploration: 0.5, score: 154
# Scores: (min: 9, avg: 27.33, max: 154)
#
# Run: 169, exploration: 0.5, score: 49
# Scores: (min: 9, avg: 27.68, max: 154)
#
# Run: 170, exploration: 0.5, score: 23
# Scores: (min: 9, avg: 27.79, max: 154)
#
# Run: 171, exploration: 0.5, score: 43
# Scores: (min: 9, avg: 28.12, max: 154)
#
# Run: 172, exploration: 0.5, score: 87
# Scores: (min: 9, avg: 28.89, max: 154)
#
# Run: 173, exploration: 0.5, score: 29
# Scores: (min: 9, avg: 29.01, max: 154)
#
# Run: 174, exploration: 0.5, score: 29
# Scores: (min: 9, avg: 29.13, max: 154)
#
# Run: 175, exploration: 0.5, score: 34
# Scores: (min: 9, avg: 29.35, max: 154)
#
# Run: 176, exploration: 0.5, score: 60
# Scores: (min: 9, avg: 29.68, max: 154)
#
# Run: 177, exploration: 0.5, score: 53
# Scores: (min: 9, avg: 30.12, max: 154)
#
# Run: 178, exploration: 0.5, score: 68
# Scores: (min: 9, avg: 30.64, max: 154)
#
# Run: 179, exploration: 0.5, score: 36
# Scores: (min: 9, avg: 30.9, max: 154)
#
# Run: 180, exploration: 0.5, score: 43
# Scores: (min: 9, avg: 31.2, max: 154)
#
# Run: 181, exploration: 0.5, score: 23
# Scores: (min: 9, avg: 31.32, max: 154)
#
# Run: 182, exploration: 0.5, score: 51
# Scores: (min: 9, avg: 31.73, max: 154)
#
# Run: 183, exploration: 0.5, score: 92
# Scores: (min: 9, avg: 32.54, max: 154)
#
# Run: 184, exploration: 0.5, score: 50
# Scores: (min: 9, avg: 32.86, max: 154)
#
# Run: 185, exploration: 0.5, score: 67
# Scores: (min: 9, avg: 33.42, max: 154)
#
# Run: 186, exploration: 0.5, score: 62
# Scores: (min: 9, avg: 33.79, max: 154)
#
# Run: 187, exploration: 0.5, score: 68
# Scores: (min: 9, avg: 34.31, max: 154)
#
# Run: 188, exploration: 0.5, score: 15
# Scores: (min: 9, avg: 34.34, max: 154)
#
# Run: 189, exploration: 0.5, score: 31
# Scores: (min: 9, avg: 34.55, max: 154)
#
# Run: 190, exploration: 0.5, score: 89
# Scores: (min: 9, avg: 35.34, max: 154)
#
# Run: 191, exploration: 0.5, score: 76
# Scores: (min: 9, avg: 35.99, max: 154)
#
# Run: 192, exploration: 0.5, score: 41
# Scores: (min: 9, avg: 36.29, max: 154)
#
# Run: 193, exploration: 0.5, score: 98
# Scores: (min: 9, avg: 37.16, max: 154)
#
# Run: 194, exploration: 0.5, score: 94
# Scores: (min: 9, avg: 37.93, max: 154)
#
# Run: 195, exploration: 0.5, score: 29
# Scores: (min: 9, avg: 38.11, max: 154)
#
# Run: 196, exploration: 0.5, score: 88
# Scores: (min: 9, avg: 38.72, max: 154)
#
# Run: 197, exploration: 0.5, score: 144
# Scores: (min: 9, avg: 39.95, max: 154)
#
# Run: 198, exploration: 0.5, score: 18
# Scores: (min: 9, avg: 39.89, max: 154)
#
# Run: 199, exploration: 0.5, score: 82
# Scores: (min: 9, avg: 40.44, max: 154)
#
# Run: 200, exploration: 0.5, score: 150
# Scores: (min: 9, avg: 41.83, max: 154)
#
# Run: 201, exploration: 0.5, score: 47
# Scores: (min: 9, avg: 42.21, max: 154)
# Run: 202, exploration: 0.5, score: 131
# Scores: (min: 9, avg: 43.25, max: 154)
#
# Run: 203, exploration: 0.5, score: 36
# Scores: (min: 9, avg: 43.42, max: 154)
#
# Run: 204, exploration: 0.5, score: 148
# Scores: (min: 9, avg: 44.78, max: 154)
#
# Run: 205, exploration: 0.5, score: 15
# Scores: (min: 9, avg: 44.8, max: 154)
#
# Run: 206, exploration: 0.5, score: 17
# Scores: (min: 9, avg: 44.86, max: 154)
#
# Run: 207, exploration: 0.5, score: 129
# Scores: (min: 9, avg: 46.01, max: 154)
#
# Run: 208, exploration: 0.5, score: 117
# Scores: (min: 9, avg: 47.07, max: 154)
#
# Run: 209, exploration: 0.5, score: 67
# Scores: (min: 9, avg: 47.64, max: 154)
#
# Run: 210, exploration: 0.5, score: 98
# Scores: (min: 9, avg: 48.49, max: 154)
#
# Run: 211, exploration: 0.5, score: 88
# Scores: (min: 9, avg: 49.26, max: 154)
#
# Run: 212, exploration: 0.5, score: 168
# Scores: (min: 9, avg: 50.74, max: 168)
#
# Run: 213, exploration: 0.5, score: 173
# Scores: (min: 9, avg: 51.87, max: 173)
#
# Run: 214, exploration: 0.5, score: 120
# Scores: (min: 9, avg: 52.6, max: 173)
#
# Run: 215, exploration: 0.5, score: 56
# Scores: (min: 9, avg: 52.79, max: 173)
#
# Run: 216, exploration: 0.5, score: 43
# Scores: (min: 9, avg: 52.92, max: 173)
#
# Run: 217, exploration: 0.5, score: 103
# Scores: (min: 9, avg: 53.85, max: 173)
#
# Run: 218, exploration: 0.5, score: 33
# Scores: (min: 9, avg: 54.04, max: 173)
#
# Run: 219, exploration: 0.5, score: 64
# Scores: (min: 9, avg: 54.56, max: 173)
#
# Run: 220, exploration: 0.5, score: 116
# Scores: (min: 9, avg: 55.6, max: 173)
#
# Run: 221, exploration: 0.5, score: 89
# Scores: (min: 9, avg: 56.34, max: 173)
#
# Run: 222, exploration: 0.5, score: 21
# Scores: (min: 9, avg: 56.43, max: 173)
#
# Run: 223, exploration: 0.5, score: 120
# Scores: (min: 9, avg: 57.52, max: 173)
#
# Run: 224, exploration: 0.5, score: 179
# Scores: (min: 9, avg: 59.13, max: 179)
#
# Run: 225, exploration: 0.5, score: 67
# Scores: (min: 9, avg: 59.7, max: 179)
#
# Run: 226, exploration: 0.5, score: 182
# Scores: (min: 9, avg: 61.39, max: 182)
#
# Run: 227, exploration: 0.5, score: 153
# Scores: (min: 9, avg: 62.79, max: 182)
#
# Run: 228, exploration: 0.5, score: 79
# Scores: (min: 9, avg: 63.47, max: 182)
#
# Run: 229, exploration: 0.5, score: 133
# Scores: (min: 9, avg: 64.68, max: 182)
#
# Run: 230, exploration: 0.5, score: 94
# Scores: (min: 12, avg: 65.53, max: 182)
#
# Run: 231, exploration: 0.5, score: 103
# Scores: (min: 13, avg: 66.44, max: 182)
#
# Run: 232, exploration: 0.5, score: 233
# Scores: (min: 13, avg: 68.55, max: 233)
#
# Run: 233, exploration: 0.5, score: 189
# Scores: (min: 13, avg: 69.9, max: 233)
#
# Run: 234, exploration: 0.5, score: 173
# Scores: (min: 13, avg: 71.17, max: 233)
#
# Run: 235, exploration: 0.5, score: 131
# Scores: (min: 13, avg: 72.22, max: 233)
#
# Run: 236, exploration: 0.5, score: 85
# Scores: (min: 13, avg: 72.89, max: 233)
#
# Run: 237, exploration: 0.5, score: 141
# Scores: (min: 13, avg: 74.08, max: 233)
#
# Run: 238, exploration: 0.5, score: 97
# Scores: (min: 13, avg: 74.89, max: 233)
#
# Run: 239, exploration: 0.5, score: 117
# Scores: (min: 13, avg: 75.9, max: 233)
#
# Run: 240, exploration: 0.5, score: 103
# Scores: (min: 15, avg: 76.8, max: 233)
#
# Run: 241, exploration: 0.5, score: 152
# Scores: (min: 15, avg: 78.12, max: 233)
#
# Run: 242, exploration: 0.5, score: 165
# Scores: (min: 15, avg: 79.55, max: 233)
#
# Run: 243, exploration: 0.5, score: 52
# Scores: (min: 15, avg: 79.86, max: 233)
#
# Run: 244, exploration: 0.5, score: 40
# Scores: (min: 15, avg: 80.09, max: 233)
#
# Run: 245, exploration: 0.5, score: 88
# Scores: (min: 15, avg: 80.73, max: 233)
#
# Run: 246, exploration: 0.5, score: 188
# Scores: (min: 15, avg: 82.34, max: 233)
#
# Run: 247, exploration: 0.5, score: 58
# Scores: (min: 15, avg: 82.65, max: 233)
#
# Run: 248, exploration: 0.5, score: 127
# Scores: (min: 15, avg: 83.76, max: 233)
#
# Run: 249, exploration: 0.5, score: 221
# Scores: (min: 15, avg: 85.54, max: 233)
#
# Run: 250, exploration: 0.5, score: 115
# Scores: (min: 15, avg: 86.48, max: 233)
#
# Run: 251, exploration: 0.5, score: 64
# Scores: (min: 15, avg: 86.97, max: 233)
#
# Run: 252, exploration: 0.5, score: 164
# Scores: (min: 15, avg: 88.27, max: 233)
#
# Run: 253, exploration: 0.5, score: 136
# Scores: (min: 15, avg: 89.27, max: 233)
#
# Run: 254, exploration: 0.5, score: 117
# Scores: (min: 15, avg: 89.78, max: 233)
#
# Run: 255, exploration: 0.5, score: 203
# Scores: (min: 15, avg: 91.45, max: 233)
#
# Run: 256, exploration: 0.5, score: 39
# Scores: (min: 15, avg: 91.31, max: 233)
#
# Run: 257, exploration: 0.5, score: 92
# Scores: (min: 15, avg: 90.8, max: 233)
#
# Run: 258, exploration: 0.5, score: 56
# Scores: (min: 15, avg: 90.73, max: 233)
#
# Run: 259, exploration: 0.5, score: 243
# Scores: (min: 15, avg: 92.51, max: 243)
#
# Run: 260, exploration: 0.5, score: 23
# Scores: (min: 15, avg: 92.31, max: 243)
#
# Run: 261, exploration: 0.5, score: 194
# Scores: (min: 15, avg: 93.14, max: 243)
#
# Run: 262, exploration: 0.5, score: 215
# Scores: (min: 15, avg: 94.24, max: 243)
#
# Run: 263, exploration: 0.5, score: 114
# Scores: (min: 15, avg: 94.69, max: 243)
#
# Run: 264, exploration: 0.5, score: 120
# Scores: (min: 15, avg: 94.88, max: 243)
#
# Run: 265, exploration: 0.5, score: 22
# Scores: (min: 15, avg: 94.47, max: 243)
#
# Run: 266, exploration: 0.5, score: 170
# Scores: (min: 15, avg: 95.3, max: 243)
#
# Run: 267, exploration: 0.5, score: 361
# Scores: (min: 15, avg: 98.73, max: 361)
#
# Run: 268, exploration: 0.5, score: 21
# Scores: (min: 15, avg: 97.4, max: 361)
#
# Run: 269, exploration: 0.5, score: 256
# Scores: (min: 15, avg: 99.47, max: 361)
#
# Run: 270, exploration: 0.5, score: 13
# Scores: (min: 13, avg: 99.37, max: 361)
#
# Run: 271, exploration: 0.5, score: 270
# Scores: (min: 13, avg: 101.64, max: 361)
#
# Run: 272, exploration: 0.5, score: 82
# Scores: (min: 13, avg: 101.59, max: 361)
#
# Run: 273, exploration: 0.5, score: 101
# Scores: (min: 13, avg: 102.31, max: 361)
#
# Run: 274, exploration: 0.5, score: 118
# Scores: (min: 13, avg: 103.2, max: 361)
#
# Run: 275, exploration: 0.5, score: 155
# Scores: (min: 13, avg: 104.41, max: 361)
#
# Run: 276, exploration: 0.5, score: 24
# Scores: (min: 13, avg: 104.05, max: 361)
#
# Run: 277, exploration: 0.5, score: 164
# Scores: (min: 13, avg: 105.16, max: 361)
#
# Run: 278, exploration: 0.5, score: 13
# Scores: (min: 13, avg: 104.61, max: 361)
#
# Run: 279, exploration: 0.5, score: 139
# Scores: (min: 13, avg: 105.64, max: 361)
#
# Run: 280, exploration: 0.5, score: 47
# Scores: (min: 13, avg: 105.68, max: 361)
#
# Run: 281, exploration: 0.5, score: 196
# Scores: (min: 13, avg: 107.41, max: 361)
#
# Run: 282, exploration: 0.5, score: 42
# Scores: (min: 13, avg: 107.32, max: 361)
#
# Run: 283, exploration: 0.5, score: 87
# Scores: (min: 13, avg: 107.27, max: 361)
#
# Run: 284, exploration: 0.5, score: 172
# Scores: (min: 13, avg: 108.49, max: 361)
#
# Run: 285, exploration: 0.5, score: 171
# Scores: (min: 13, avg: 109.53, max: 361)
#
# Run: 286, exploration: 0.5, score: 52
# Scores: (min: 13, avg: 109.43, max: 361)
#
# Run: 287, exploration: 0.5, score: 12
# Scores: (min: 12, avg: 108.87, max: 361)
#
# Run: 288, exploration: 0.5, score: 134
# Scores: (min: 12, avg: 110.06, max: 361)
#
# Run: 289, exploration: 0.5, score: 234
# Scores: (min: 12, avg: 112.09, max: 361)
#
# Run: 290, exploration: 0.5, score: 146
# Scores: (min: 12, avg: 112.66, max: 361)
#
# Run: 291, exploration: 0.5, score: 192
# Scores: (min: 12, avg: 113.82, max: 361)
#
# Run: 292, exploration: 0.5, score: 53
# Scores: (min: 12, avg: 113.94, max: 361)
#
# Run: 293, exploration: 0.5, score: 68
# Scores: (min: 12, avg: 113.64, max: 361)
#
# Run: 294, exploration: 0.5, score: 26
# Scores: (min: 12, avg: 112.96, max: 361)
#
# Run: 295, exploration: 0.5, score: 11
# Scores: (min: 11, avg: 112.78, max: 361)
#
# Run: 296, exploration: 0.5, score: 206
# Scores: (min: 11, avg: 113.96, max: 361)
#
# Run: 297, exploration: 0.5, score: 26
# Scores: (min: 11, avg: 112.78, max: 361)
#
# Run: 298, exploration: 0.5, score: 126
# Scores: (min: 11, avg: 113.86, max: 361)
#
# Run: 299, exploration: 0.5, score: 166
# Scores: (min: 11, avg: 114.7, max: 361)
#
# Run: 300, exploration: 0.5, score: 150
# Scores: (min: 11, avg: 114.7, max: 361)
#
# Run: 301, exploration: 0.5, score: 190
# Scores: (min: 11, avg: 116.13, max: 361)
#
# Run: 302, exploration: 0.5, score: 45
# Scores: (min: 11, avg: 115.27, max: 361)
#
# Run: 303, exploration: 0.5, score: 220
# Scores: (min: 11, avg: 117.11, max: 361)
#
# Run: 304, exploration: 0.5, score: 14
# Scores: (min: 11, avg: 115.77, max: 361)
#
# Run: 305, exploration: 0.5, score: 121
# Scores: (min: 11, avg: 116.83, max: 361)
# Run: 306, exploration: 0.5, score: 68
# Scores: (min: 11, avg: 117.34, max: 361)
#
# Run: 307, exploration: 0.5, score: 209
# Scores: (min: 11, avg: 118.14, max: 361)
#
# Run: 308, exploration: 0.5, score: 56
# Scores: (min: 11, avg: 117.53, max: 361)
#
# Run: 309, exploration: 0.5, score: 233
# Scores: (min: 11, avg: 119.19, max: 361)
#
# Run: 310, exploration: 0.5, score: 49
# Scores: (min: 11, avg: 118.7, max: 361)
#
# Run: 311, exploration: 0.5, score: 103
# Scores: (min: 11, avg: 118.85, max: 361)
#
# Run: 312, exploration: 0.5, score: 190
# Scores: (min: 11, avg: 119.07, max: 361)
#
# Run: 313, exploration: 0.5, score: 350
# Scores: (min: 11, avg: 120.84, max: 361)
#
# Run: 314, exploration: 0.5, score: 159
# Scores: (min: 11, avg: 121.23, max: 361)
#
# Run: 315, exploration: 0.5, score: 152
# Scores: (min: 11, avg: 122.19, max: 361)
#
# Run: 316, exploration: 0.5, score: 91
# Scores: (min: 11, avg: 122.67, max: 361)
#
# Run: 317, exploration: 0.5, score: 93
# Scores: (min: 11, avg: 122.57, max: 361)
#
# Run: 318, exploration: 0.5, score: 208
# Scores: (min: 11, avg: 124.32, max: 361)
#
# Run: 319, exploration: 0.5, score: 393
# Scores: (min: 11, avg: 127.61, max: 393)
#
# Run: 320, exploration: 0.5, score: 172
# Scores: (min: 11, avg: 128.17, max: 393)
#
# Run: 321, exploration: 0.5, score: 101
# Scores: (min: 11, avg: 128.29, max: 393)
#
# Run: 322, exploration: 0.5, score: 59
# Scores: (min: 11, avg: 128.67, max: 393)
#
# Run: 323, exploration: 0.5, score: 32
# Scores: (min: 11, avg: 127.79, max: 393)
#
# Run: 324, exploration: 0.5, score: 66
# Scores: (min: 11, avg: 126.66, max: 393)
#
# Run: 325, exploration: 0.5, score: 82
# Scores: (min: 11, avg: 126.81, max: 393)
#
# Run: 326, exploration: 0.5, score: 212
# Scores: (min: 11, avg: 127.11, max: 393)
#
# Run: 327, exploration: 0.5, score: 244
# Scores: (min: 11, avg: 128.02, max: 393)
#
# Run: 328, exploration: 0.5, score: 137
# Scores: (min: 11, avg: 128.6, max: 393)
#
# Run: 329, exploration: 0.5, score: 25
# Scores: (min: 11, avg: 127.52, max: 393)
#
# Run: 330, exploration: 0.5, score: 101
# Scores: (min: 11, avg: 127.59, max: 393)
#
# Run: 331, exploration: 0.5, score: 92
# Scores: (min: 11, avg: 127.48, max: 393)
#
# Run: 332, exploration: 0.5, score: 125
# Scores: (min: 11, avg: 126.4, max: 393)
#
# Run: 333, exploration: 0.5, score: 107
# Scores: (min: 11, avg: 125.58, max: 393)
#
# Run: 334, exploration: 0.5, score: 127
# Scores: (min: 11, avg: 125.12, max: 393)
#
# Run: 335, exploration: 0.5, score: 255
# Scores: (min: 11, avg: 126.36, max: 393)
#
# Run: 336, exploration: 0.5, score: 55
# Scores: (min: 11, avg: 126.06, max: 393)
#
# Run: 337, exploration: 0.5, score: 111
# Scores: (min: 11, avg: 125.76, max: 393)
#
# Run: 338, exploration: 0.5, score: 82
# Scores: (min: 11, avg: 125.61, max: 393)
#
# Run: 339, exploration: 0.5, score: 372
# Scores: (min: 11, avg: 128.16, max: 393)
#
# Run: 340, exploration: 0.5, score: 169
# Scores: (min: 11, avg: 128.82, max: 393)
#
# Run: 341, exploration: 0.5, score: 232
# Scores: (min: 11, avg: 129.62, max: 393)
#
# Run: 342, exploration: 0.5, score: 243
# Scores: (min: 11, avg: 130.4, max: 393)
#
# Run: 343, exploration: 0.5, score: 38
# Scores: (min: 11, avg: 130.26, max: 393)
#
# Run: 344, exploration: 0.5, score: 229
# Scores: (min: 11, avg: 132.15, max: 393)
#
# Run: 345, exploration: 0.5, score: 185
# Scores: (min: 11, avg: 133.12, max: 393)
#
# Run: 346, exploration: 0.5, score: 84
# Scores: (min: 11, avg: 132.08, max: 393)
#
# Run: 347, exploration: 0.5, score: 95
# Scores: (min: 11, avg: 132.45, max: 393)
#
# Run: 348, exploration: 0.5, score: 227
# Scores: (min: 11, avg: 133.45, max: 393)
#
# Run: 349, exploration: 0.5, score: 191
# Scores: (min: 11, avg: 133.15, max: 393)
#
# Run: 350, exploration: 0.5, score: 247
# Scores: (min: 11, avg: 134.47, max: 393)
#
# Run: 351, exploration: 0.5, score: 30
# Scores: (min: 11, avg: 134.13, max: 393)
#
# Run: 352, exploration: 0.5, score: 88
# Scores: (min: 11, avg: 133.37, max: 393)
#
# Run: 353, exploration: 0.5, score: 65
# Scores: (min: 11, avg: 132.66, max: 393)
#
# Run: 354, exploration: 0.5, score: 282
# Scores: (min: 11, avg: 134.31, max: 393)
#
# Run: 355, exploration: 0.5, score: 182
# Scores: (min: 11, avg: 134.1, max: 393)
#
# Run: 356, exploration: 0.5, score: 47
# Scores: (min: 11, avg: 134.18, max: 393)
#
# Run: 357, exploration: 0.5, score: 57
# Scores: (min: 11, avg: 133.83, max: 393)
#
# Run: 358, exploration: 0.5, score: 168
# Scores: (min: 11, avg: 134.95, max: 393)
#
# Run: 359, exploration: 0.5, score: 68
# Scores: (min: 11, avg: 133.2, max: 393)
#
# Run: 360, exploration: 0.5, score: 189
# Scores: (min: 11, avg: 134.86, max: 393)
#
# Run: 361, exploration: 0.5, score: 182
# Scores: (min: 11, avg: 134.74, max: 393)
#
# Run: 362, exploration: 0.5, score: 18
# Scores: (min: 11, avg: 132.77, max: 393)
#
# Run: 363, exploration: 0.5, score: 164
# Scores: (min: 11, avg: 133.27, max: 393)
#
# Run: 364, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 137.07, max: 500)
#
# Run: 365, exploration: 0.5, score: 48
# Scores: (min: 11, avg: 137.33, max: 500)
#
# Run: 366, exploration: 0.5, score: 208
# Scores: (min: 11, avg: 137.71, max: 500)
#
# Run: 367, exploration: 0.5, score: 322
# Scores: (min: 11, avg: 137.32, max: 500)
#
# Run: 368, exploration: 0.5, score: 396
# Scores: (min: 11, avg: 141.07, max: 500)
#
# Run: 369, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 143.51, max: 500)
#
# Run: 370, exploration: 0.5, score: 137
# Scores: (min: 11, avg: 144.75, max: 500)
#
# Run: 371, exploration: 0.5, score: 62
# Scores: (min: 11, avg: 142.67, max: 500)
#
# Run: 372, exploration: 0.5, score: 281
# Scores: (min: 11, avg: 144.66, max: 500)
#
# Run: 373, exploration: 0.5, score: 227
# Scores: (min: 11, avg: 145.92, max: 500)
#
# Run: 374, exploration: 0.5, score: 233
# Scores: (min: 11, avg: 147.07, max: 500)
#
# Run: 375, exploration: 0.5, score: 425
# Scores: (min: 11, avg: 149.77, max: 500)
#
# Run: 376, exploration: 0.5, score: 192
# Scores: (min: 11, avg: 151.45, max: 500)
#
# Run: 377, exploration: 0.5, score: 239
# Scores: (min: 11, avg: 152.2, max: 500)
#
# Run: 378, exploration: 0.5, score: 12
# Scores: (min: 11, avg: 152.19, max: 500)
#
# Run: 379, exploration: 0.5, score: 80
# Scores: (min: 11, avg: 151.6, max: 500)
#
# Run: 380, exploration: 0.5, score: 361
# Scores: (min: 11, avg: 154.74, max: 500)
#
# Run: 381, exploration: 0.5, score: 309
# Scores: (min: 11, avg: 155.87, max: 500)
#
# Run: 382, exploration: 0.5, score: 182
# Scores: (min: 11, avg: 157.27, max: 500)
#
# Run: 383, exploration: 0.5, score: 111
# Scores: (min: 11, avg: 157.51, max: 500)
#
# Run: 384, exploration: 0.5, score: 63
# Scores: (min: 11, avg: 156.42, max: 500)
#
# Run: 385, exploration: 0.5, score: 295
# Scores: (min: 11, avg: 157.66, max: 500)
#
# Run: 386, exploration: 0.5, score: 110
# Scores: (min: 11, avg: 158.24, max: 500)
#
# Run: 387, exploration: 0.5, score: 90
# Scores: (min: 11, avg: 159.02, max: 500)
#
# Run: 388, exploration: 0.5, score: 221
# Scores: (min: 11, avg: 159.89, max: 500)
#
# Run: 389, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 162.55, max: 500)
#
# Run: 390, exploration: 0.5, score: 15
# Scores: (min: 11, avg: 161.24, max: 500)
#
# Run: 391, exploration: 0.5, score: 298
# Scores: (min: 11, avg: 162.3, max: 500)
#
# Run: 392, exploration: 0.5, score: 27
# Scores: (min: 11, avg: 162.04, max: 500)
#
# Run: 393, exploration: 0.5, score: 44
# Scores: (min: 11, avg: 161.8, max: 500)
#
# Run: 394, exploration: 0.5, score: 306
# Scores: (min: 11, avg: 164.6, max: 500)
#
# Run: 395, exploration: 0.5, score: 291
# Scores: (min: 12, avg: 167.4, max: 500)
#
# Run: 396, exploration: 0.5, score: 70
# Scores: (min: 12, avg: 166.04, max: 500)
#
# Run: 397, exploration: 0.5, score: 16
# Scores: (min: 12, avg: 165.94, max: 500)
#
# Run: 398, exploration: 0.5, score: 349
# Scores: (min: 12, avg: 168.17, max: 500)
#
# Run: 399, exploration: 0.5, score: 338
# Scores: (min: 12, avg: 169.89, max: 500)
#
# Run: 400, exploration: 0.5, score: 453
# Scores: (min: 12, avg: 172.92, max: 500)
#
# Run: 401, exploration: 0.5, score: 86
# Scores: (min: 12, avg: 171.88, max: 500)
#
# Run: 402, exploration: 0.5, score: 76
# Scores: (min: 12, avg: 172.19, max: 500)
#
# Run: 403, exploration: 0.5, score: 28
# Scores: (min: 12, avg: 170.27, max: 500)
#
# Run: 404, exploration: 0.5, score: 136
# Scores: (min: 12, avg: 171.49, max: 500)
#
# Run: 405, exploration: 0.5, score: 193
# Scores: (min: 12, avg: 172.21, max: 500)
#
# Run: 406, exploration: 0.5, score: 81
# Scores: (min: 12, avg: 172.34, max: 500)
#
# Run: 407, exploration: 0.5, score: 500
# Scores: (min: 12, avg: 175.25, max: 500)
# Run: 408, exploration: 0.5, score: 36
# Scores: (min: 12, avg: 175.05, max: 500)
#
# Run: 409, exploration: 0.5, score: 495
# Scores: (min: 12, avg: 177.67, max: 500)
#
# Run: 410, exploration: 0.5, score: 204
# Scores: (min: 12, avg: 179.22, max: 500)
#
# Run: 411, exploration: 0.5, score: 86
# Scores: (min: 12, avg: 179.05, max: 500)
#
# Run: 412, exploration: 0.5, score: 343
# Scores: (min: 12, avg: 180.58, max: 500)
#
# Run: 413, exploration: 0.5, score: 253
# Scores: (min: 12, avg: 179.61, max: 500)
#
# Run: 414, exploration: 0.5, score: 91
# Scores: (min: 12, avg: 178.93, max: 500)
#
# Run: 415, exploration: 0.5, score: 114
# Scores: (min: 12, avg: 178.55, max: 500)
#
# Run: 416, exploration: 0.5, score: 14
# Scores: (min: 12, avg: 177.78, max: 500)
#
# Run: 417, exploration: 0.5, score: 23
# Scores: (min: 12, avg: 177.08, max: 500)
#
# Run: 418, exploration: 0.5, score: 94
# Scores: (min: 12, avg: 175.94, max: 500)
#
# Run: 419, exploration: 0.5, score: 88
# Scores: (min: 12, avg: 172.89, max: 500)
#
# Run: 420, exploration: 0.5, score: 25
# Scores: (min: 12, avg: 171.42, max: 500)
#
# Run: 421, exploration: 0.5, score: 219
# Scores: (min: 12, avg: 172.6, max: 500)
#
# Run: 422, exploration: 0.5, score: 129
# Scores: (min: 12, avg: 173.3, max: 500)
#
# Run: 423, exploration: 0.5, score: 204
# Scores: (min: 12, avg: 175.02, max: 500)
#
# Run: 424, exploration: 0.5, score: 260
# Scores: (min: 12, avg: 176.96, max: 500)
#
# Run: 425, exploration: 0.5, score: 32
# Scores: (min: 12, avg: 176.46, max: 500)
#
# Run: 426, exploration: 0.5, score: 39
# Scores: (min: 12, avg: 174.73, max: 500)
#
# Run: 427, exploration: 0.5, score: 26
# Scores: (min: 12, avg: 172.55, max: 500)
#
# Run: 428, exploration: 0.5, score: 190
# Scores: (min: 12, avg: 173.08, max: 500)
#
# Run: 429, exploration: 0.5, score: 33
# Scores: (min: 12, avg: 173.16, max: 500)
#
# Run: 430, exploration: 0.5, score: 93
# Scores: (min: 12, avg: 173.08, max: 500)
#
# Run: 431, exploration: 0.5, score: 83
# Scores: (min: 12, avg: 172.99, max: 500)
#
# Run: 432, exploration: 0.5, score: 45
# Scores: (min: 12, avg: 172.19, max: 500)
#
# Run: 433, exploration: 0.5, score: 74
# Scores: (min: 12, avg: 171.86, max: 500)
#
# Run: 434, exploration: 0.5, score: 25
# Scores: (min: 12, avg: 170.84, max: 500)
#
# Run: 435, exploration: 0.5, score: 183
# Scores: (min: 12, avg: 170.12, max: 500)
#
# Run: 436, exploration: 0.5, score: 204
# Scores: (min: 12, avg: 171.61, max: 500)
#
# Run: 437, exploration: 0.5, score: 323
# Scores: (min: 12, avg: 173.73, max: 500)
#
# Run: 438, exploration: 0.5, score: 27
# Scores: (min: 12, avg: 173.18, max: 500)
#
# Run: 439, exploration: 0.5, score: 70
# Scores: (min: 12, avg: 170.16, max: 500)
#
# Run: 440, exploration: 0.5, score: 23
# Scores: (min: 12, avg: 168.7, max: 500)
#
# Run: 441, exploration: 0.5, score: 322
# Scores: (min: 12, avg: 169.6, max: 500)
#
# Run: 442, exploration: 0.5, score: 52
# Scores: (min: 12, avg: 167.69, max: 500)
#
# Run: 443, exploration: 0.5, score: 202
# Scores: (min: 12, avg: 169.33, max: 500)
#
# Run: 444, exploration: 0.5, score: 117
# Scores: (min: 12, avg: 168.21, max: 500)
#
# Run: 445, exploration: 0.5, score: 100
# Scores: (min: 12, avg: 167.36, max: 500)
#
# Run: 446, exploration: 0.5, score: 428
# Scores: (min: 12, avg: 170.8, max: 500)
#
# Run: 447, exploration: 0.5, score: 254
# Scores: (min: 12, avg: 172.39, max: 500)
#
# Run: 448, exploration: 0.5, score: 54
# Scores: (min: 12, avg: 170.66, max: 500)
#
# Run: 449, exploration: 0.5, score: 77
# Scores: (min: 12, avg: 169.52, max: 500)
#
# Run: 450, exploration: 0.5, score: 15
# Scores: (min: 12, avg: 167.2, max: 500)
#
# Run: 451, exploration: 0.5, score: 163
# Scores: (min: 12, avg: 168.53, max: 500)
#
# Run: 452, exploration: 0.5, score: 265
# Scores: (min: 12, avg: 170.3, max: 500)
#
# Run: 453, exploration: 0.5, score: 32
# Scores: (min: 12, avg: 169.97, max: 500)
#
# Run: 454, exploration: 0.5, score: 42
# Scores: (min: 12, avg: 167.57, max: 500)
#
# Run: 455, exploration: 0.5, score: 127
# Scores: (min: 12, avg: 167.02, max: 500)
#
# Run: 456, exploration: 0.5, score: 57
# Scores: (min: 12, avg: 167.12, max: 500)
#
# Run: 457, exploration: 0.5, score: 500
# Scores: (min: 12, avg: 171.55, max: 500)
#
# Run: 458, exploration: 0.5, score: 69
# Scores: (min: 12, avg: 170.56, max: 500)
#
# Run: 459, exploration: 0.5, score: 53
# Scores: (min: 12, avg: 170.41, max: 500)
#
# Run: 460, exploration: 0.5, score: 29
# Scores: (min: 12, avg: 168.81, max: 500)
#
# Run: 461, exploration: 0.5, score: 363
# Scores: (min: 12, avg: 170.62, max: 500)
#
# Run: 462, exploration: 0.5, score: 247
# Scores: (min: 12, avg: 172.91, max: 500)
#
# Run: 463, exploration: 0.5, score: 316
# Scores: (min: 12, avg: 174.43, max: 500)
#
# Run: 464, exploration: 0.5, score: 162
# Scores: (min: 12, avg: 171.05, max: 500)
#
# Run: 465, exploration: 0.5, score: 179
# Scores: (min: 12, avg: 172.36, max: 500)
#
# Run: 466, exploration: 0.5, score: 400
# Scores: (min: 12, avg: 174.28, max: 500)
#
# Run: 467, exploration: 0.5, score: 216
# Scores: (min: 12, avg: 173.22, max: 500)
#
# Run: 468, exploration: 0.5, score: 199
# Scores: (min: 12, avg: 171.25, max: 500)
#
# Run: 469, exploration: 0.5, score: 45
# Scores: (min: 12, avg: 166.7, max: 500)
#
# Run: 470, exploration: 0.5, score: 253
# Scores: (min: 12, avg: 167.86, max: 500)
#
# Run: 471, exploration: 0.5, score: 295
# Scores: (min: 12, avg: 170.19, max: 500)
#
# Run: 472, exploration: 0.5, score: 41
# Scores: (min: 12, avg: 167.79, max: 500)
#
# Run: 473, exploration: 0.5, score: 260
# Scores: (min: 12, avg: 168.12, max: 500)
#
# Run: 474, exploration: 0.5, score: 75
# Scores: (min: 12, avg: 166.54, max: 500)
#
# Run: 475, exploration: 0.5, score: 66
# Scores: (min: 12, avg: 162.95, max: 500)
#
# Run: 476, exploration: 0.5, score: 48
# Scores: (min: 12, avg: 161.51, max: 500)
#
# Run: 477, exploration: 0.5, score: 217
# Scores: (min: 12, avg: 161.29, max: 500)
#
# Run: 478, exploration: 0.5, score: 26
# Scores: (min: 14, avg: 161.43, max: 500)
#
# Run: 479, exploration: 0.5, score: 132
# Scores: (min: 14, avg: 161.95, max: 500)
#
# Run: 480, exploration: 0.5, score: 282
# Scores: (min: 14, avg: 161.16, max: 500)
#
# Run: 481, exploration: 0.5, score: 224
# Scores: (min: 14, avg: 160.31, max: 500)
#
# Run: 482, exploration: 0.5, score: 48
# Scores: (min: 14, avg: 158.97, max: 500)
#
# Run: 483, exploration: 0.5, score: 280
# Scores: (min: 14, avg: 160.66, max: 500)
#
# Run: 484, exploration: 0.5, score: 25
# Scores: (min: 14, avg: 160.28, max: 500)
#
# Run: 485, exploration: 0.5, score: 216
# Scores: (min: 14, avg: 159.49, max: 500)
#
# Run: 486, exploration: 0.5, score: 98
# Scores: (min: 14, avg: 159.37, max: 500)
#
# Run: 487, exploration: 0.5, score: 210
# Scores: (min: 14, avg: 160.57, max: 500)
#
# Run: 488, exploration: 0.5, score: 148
# Scores: (min: 14, avg: 159.84, max: 500)
#
# Run: 489, exploration: 0.5, score: 32
# Scores: (min: 14, avg: 155.16, max: 500)
#
# Run: 490, exploration: 0.5, score: 325
# Scores: (min: 14, avg: 158.26, max: 500)
#
# Run: 491, exploration: 0.5, score: 32
# Scores: (min: 14, avg: 155.6, max: 500)
#
# Run: 492, exploration: 0.5, score: 310
# Scores: (min: 14, avg: 158.43, max: 500)
#
# Run: 493, exploration: 0.5, score: 159
# Scores: (min: 14, avg: 159.58, max: 500)
#
# Run: 494, exploration: 0.5, score: 67
# Scores: (min: 14, avg: 157.19, max: 500)
#
# Run: 495, exploration: 0.5, score: 26
# Scores: (min: 14, avg: 154.54, max: 500)
#
# Run: 496, exploration: 0.5, score: 307
# Scores: (min: 14, avg: 156.91, max: 500)
#
# Run: 497, exploration: 0.5, score: 342
# Scores: (min: 14, avg: 160.17, max: 500)
#
# Run: 498, exploration: 0.5, score: 18
# Scores: (min: 14, avg: 156.86, max: 500)
#
# Run: 499, exploration: 0.5, score: 480
# Scores: (min: 14, avg: 158.28, max: 500)
#
# Run: 500, exploration: 0.5, score: 58
# Scores: (min: 14, avg: 154.33, max: 500)
#
# Run: 501, exploration: 0.5, score: 152
# Scores: (min: 14, avg: 154.99, max: 500)
#
# Run: 502, exploration: 0.5, score: 244
# Scores: (min: 14, avg: 156.67, max: 500)
#
# Run: 503, exploration: 0.5, score: 96
# Scores: (min: 14, avg: 157.35, max: 500)
#
# Run: 504, exploration: 0.5, score: 82
# Scores: (min: 14, avg: 156.81, max: 500)
#
# Run: 505, exploration: 0.5, score: 359
# Scores: (min: 14, avg: 158.47, max: 500)
#
# Run: 506, exploration: 0.5, score: 45
# Scores: (min: 14, avg: 158.11, max: 500)
#
# Run: 507, exploration: 0.5, score: 41
# Scores: (min: 14, avg: 153.52, max: 500)
#
# Run: 508, exploration: 0.5, score: 72
# Scores: (min: 14, avg: 153.88, max: 500)
#
# Run: 509, exploration: 0.5, score: 375
# Scores: (min: 14, avg: 152.68, max: 500)
# Run: 510, exploration: 0.5, score: 151
# Scores: (min: 14, avg: 152.15, max: 500)
#
# Run: 511, exploration: 0.5, score: 217
# Scores: (min: 14, avg: 153.46, max: 500)
#
# Run: 512, exploration: 0.5, score: 174
# Scores: (min: 14, avg: 151.77, max: 500)
#
# Run: 513, exploration: 0.5, score: 412
# Scores: (min: 14, avg: 153.36, max: 500)
#
# Run: 514, exploration: 0.5, score: 167
# Scores: (min: 14, avg: 154.12, max: 500)
#
# Run: 515, exploration: 0.5, score: 27
# Scores: (min: 14, avg: 153.25, max: 500)
#
# Run: 516, exploration: 0.5, score: 265
# Scores: (min: 15, avg: 155.76, max: 500)
#
# Run: 517, exploration: 0.5, score: 46
# Scores: (min: 15, avg: 155.99, max: 500)
#
# Run: 518, exploration: 0.5, score: 75
# Scores: (min: 15, avg: 155.8, max: 500)
#
# Run: 519, exploration: 0.5, score: 68
# Scores: (min: 15, avg: 155.6, max: 500)
#
# Run: 520, exploration: 0.5, score: 269
# Scores: (min: 15, avg: 158.04, max: 500)
#
# Run: 521, exploration: 0.5, score: 374
# Scores: (min: 15, avg: 159.59, max: 500)
#
# Run: 522, exploration: 0.5, score: 192
# Scores: (min: 15, avg: 160.22, max: 500)
#
# Run: 523, exploration: 0.5, score: 437
# Scores: (min: 15, avg: 162.55, max: 500)
#
# Run: 524, exploration: 0.5, score: 250
# Scores: (min: 15, avg: 162.45, max: 500)
#
# Run: 525, exploration: 0.5, score: 216
# Scores: (min: 15, avg: 164.29, max: 500)
#
# Run: 526, exploration: 0.5, score: 11
# Scores: (min: 11, avg: 164.01, max: 500)
#
# Run: 527, exploration: 0.5, score: 419
# Scores: (min: 11, avg: 167.94, max: 500)
#
# Run: 528, exploration: 0.5, score: 75
# Scores: (min: 11, avg: 166.79, max: 500)
#
# Run: 529, exploration: 0.5, score: 248
# Scores: (min: 11, avg: 168.94, max: 500)
#
# Run: 530, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 173.01, max: 500)
#
# Run: 531, exploration: 0.5, score: 63
# Scores: (min: 11, avg: 172.81, max: 500)
#
# Run: 532, exploration: 0.5, score: 396
# Scores: (min: 11, avg: 176.32, max: 500)
#
# Run: 533, exploration: 0.5, score: 131
# Scores: (min: 11, avg: 176.89, max: 500)
#
# Run: 534, exploration: 0.5, score: 27
# Scores: (min: 11, avg: 176.91, max: 500)
#
# Run: 535, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 180.08, max: 500)
#
# Run: 536, exploration: 0.5, score: 142
# Scores: (min: 11, avg: 179.46, max: 500)
#
# Run: 537, exploration: 0.5, score: 93
# Scores: (min: 11, avg: 177.16, max: 500)
#
# Run: 538, exploration: 0.5, score: 179
# Scores: (min: 11, avg: 178.68, max: 500)
#
# Run: 539, exploration: 0.5, score: 23
# Scores: (min: 11, avg: 178.21, max: 500)
#
# Run: 540, exploration: 0.5, score: 93
# Scores: (min: 11, avg: 178.91, max: 500)
#
# Run: 541, exploration: 0.5, score: 59
# Scores: (min: 11, avg: 176.28, max: 500)
#
# Run: 542, exploration: 0.5, score: 482
# Scores: (min: 11, avg: 180.58, max: 500)
#
# Run: 543, exploration: 0.5, score: 357
# Scores: (min: 11, avg: 182.13, max: 500)
#
# Run: 544, exploration: 0.5, score: 195
# Scores: (min: 11, avg: 182.91, max: 500)
#
# Run: 545, exploration: 0.5, score: 61
# Scores: (min: 11, avg: 182.52, max: 500)
#
# Run: 546, exploration: 0.5, score: 134
# Scores: (min: 11, avg: 179.58, max: 500)
#
# Run: 547, exploration: 0.5, score: 253
# Scores: (min: 11, avg: 179.57, max: 500)
#
# Run: 548, exploration: 0.5, score: 65
# Scores: (min: 11, avg: 179.68, max: 500)
#
# Run: 549, exploration: 0.5, score: 71
# Scores: (min: 11, avg: 179.62, max: 500)
#
# Run: 550, exploration: 0.5, score: 111
# Scores: (min: 11, avg: 180.58, max: 500)
#
# Run: 551, exploration: 0.5, score: 75
# Scores: (min: 11, avg: 179.7, max: 500)
#
# Run: 552, exploration: 0.5, score: 188
# Scores: (min: 11, avg: 178.93, max: 500)
#
# Run: 553, exploration: 0.5, score: 126
# Scores: (min: 11, avg: 179.87, max: 500)
#
# Run: 554, exploration: 0.5, score: 314
# Scores: (min: 11, avg: 182.59, max: 500)
#
# Run: 555, exploration: 0.5, score: 74
# Scores: (min: 11, avg: 182.06, max: 500)
#
# Run: 556, exploration: 0.5, score: 269
# Scores: (min: 11, avg: 184.18, max: 500)
#
# Run: 557, exploration: 0.5, score: 83
# Scores: (min: 11, avg: 180.01, max: 500)
#
# Run: 558, exploration: 0.5, score: 318
# Scores: (min: 11, avg: 182.5, max: 500)
#
# Run: 559, exploration: 0.5, score: 158
# Scores: (min: 11, avg: 183.55, max: 500)
#
# Run: 560, exploration: 0.5, score: 224
# Scores: (min: 11, avg: 185.5, max: 500)
#
# Run: 561, exploration: 0.5, score: 187
# Scores: (min: 11, avg: 183.74, max: 500)
#
# Run: 562, exploration: 0.5, score: 46
# Scores: (min: 11, avg: 181.73, max: 500)
#
# Run: 563, exploration: 0.5, score: 195
# Scores: (min: 11, avg: 180.52, max: 500)
#
# Run: 564, exploration: 0.5, score: 110
# Scores: (min: 11, avg: 180, max: 500)
#
# Run: 565, exploration: 0.5, score: 291
# Scores: (min: 11, avg: 181.12, max: 500)
#
# Run: 566, exploration: 0.5, score: 162
# Scores: (min: 11, avg: 178.74, max: 500)
#
# Run: 567, exploration: 0.5, score: 165
# Scores: (min: 11, avg: 178.23, max: 500)
#
# Run: 568, exploration: 0.5, score: 244
# Scores: (min: 11, avg: 178.68, max: 500)
#
# Run: 569, exploration: 0.5, score: 334
# Scores: (min: 11, avg: 181.57, max: 500)
#
# Run: 570, exploration: 0.5, score: 103
# Scores: (min: 11, avg: 180.07, max: 500)
#
# Run: 571, exploration: 0.5, score: 54
# Scores: (min: 11, avg: 177.66, max: 500)
#
# Run: 572, exploration: 0.5, score: 136
# Scores: (min: 11, avg: 178.61, max: 500)
#
# Run: 573, exploration: 0.5, score: 100
# Scores: (min: 11, avg: 177.01, max: 500)
#
# Run: 574, exploration: 0.5, score: 31
# Scores: (min: 11, avg: 176.57, max: 500)
#
# Run: 575, exploration: 0.5, score: 216
# Scores: (min: 11, avg: 178.07, max: 500)
#
# Run: 576, exploration: 0.5, score: 229
# Scores: (min: 11, avg: 179.88, max: 500)
#
# Run: 577, exploration: 0.5, score: 195
# Scores: (min: 11, avg: 179.66, max: 500)
#
# Run: 578, exploration: 0.5, score: 58
# Scores: (min: 11, avg: 179.98, max: 500)
#
# Run: 579, exploration: 0.5, score: 53
# Scores: (min: 11, avg: 179.19, max: 500)
#
# Run: 580, exploration: 0.5, score: 149
# Scores: (min: 11, avg: 177.86, max: 500)
#
# Run: 581, exploration: 0.5, score: 245
# Scores: (min: 11, avg: 178.07, max: 500)
#
# Run: 582, exploration: 0.5, score: 186
# Scores: (min: 11, avg: 179.45, max: 500)
#
# Run: 583, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 181.65, max: 500)
#
# Run: 584, exploration: 0.5, score: 23
# Scores: (min: 11, avg: 181.63, max: 500)
#
# Run: 585, exploration: 0.5, score: 18
# Scores: (min: 11, avg: 179.65, max: 500)
#
# Run: 586, exploration: 0.5, score: 427
# Scores: (min: 11, avg: 182.94, max: 500)
#
# Run: 587, exploration: 0.5, score: 23
# Scores: (min: 11, avg: 181.07, max: 500)
#
# Run: 588, exploration: 0.5, score: 175
# Scores: (min: 11, avg: 181.34, max: 500)
#
# Run: 589, exploration: 0.5, score: 182
# Scores: (min: 11, avg: 182.84, max: 500)
#
# Run: 590, exploration: 0.5, score: 297
# Scores: (min: 11, avg: 182.56, max: 500)
#
# Run: 591, exploration: 0.5, score: 183
# Scores: (min: 11, avg: 184.07, max: 500)
#
# Run: 592, exploration: 0.5, score: 37
# Scores: (min: 11, avg: 181.34, max: 500)
#
# Run: 593, exploration: 0.5, score: 46
# Scores: (min: 11, avg: 180.21, max: 500)
#
# Run: 594, exploration: 0.5, score: 327
# Scores: (min: 11, avg: 182.81, max: 500)
#
# Run: 595, exploration: 0.5, score: 152
# Scores: (min: 11, avg: 184.07, max: 500)
#
# Run: 596, exploration: 0.5, score: 389
# Scores: (min: 11, avg: 184.89, max: 500)
#
# Run: 597, exploration: 0.5, score: 204
# Scores: (min: 11, avg: 183.51, max: 500)
#
# Run: 598, exploration: 0.5, score: 58
# Scores: (min: 11, avg: 183.91, max: 500)
#
# Run: 599, exploration: 0.5, score: 220
# Scores: (min: 11, avg: 181.31, max: 500)
#
# Run: 600, exploration: 0.5, score: 148
# Scores: (min: 11, avg: 182.21, max: 500)
#
# Run: 601, exploration: 0.5, score: 82
# Scores: (min: 11, avg: 181.51, max: 500)
#
# Run: 602, exploration: 0.5, score: 50
# Scores: (min: 11, avg: 179.57, max: 500)
#
# Run: 603, exploration: 0.5, score: 386
# Scores: (min: 11, avg: 182.47, max: 500)
#
# Run: 604, exploration: 0.5, score: 352
# Scores: (min: 11, avg: 185.17, max: 500)
#
# Run: 605, exploration: 0.5, score: 205
# Scores: (min: 11, avg: 183.63, max: 500)
#
# Run: 606, exploration: 0.5, score: 126
# Scores: (min: 11, avg: 184.44, max: 500)
#
# Run: 607, exploration: 0.5, score: 137
# Scores: (min: 11, avg: 185.4, max: 500)
#
# Run: 608, exploration: 0.5, score: 289
# Scores: (min: 11, avg: 187.57, max: 500)
#
# Run: 609, exploration: 0.5, score: 374
# Scores: (min: 11, avg: 187.56, max: 500)
#
# Run: 610, exploration: 0.5, score: 274
# Scores: (min: 11, avg: 188.79, max: 500)
#
# Run: 611, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 191.62, max: 500)
# Run: 612, exploration: 0.5, score: 152
# Scores: (min: 11, avg: 191.4, max: 500)
#
# Run: 613, exploration: 0.5, score: 158
# Scores: (min: 11, avg: 188.86, max: 500)
#
# Run: 614, exploration: 0.5, score: 159
# Scores: (min: 11, avg: 188.78, max: 500)
#
# Run: 615, exploration: 0.5, score: 272
# Scores: (min: 11, avg: 191.23, max: 500)
#
# Run: 616, exploration: 0.5, score: 137
# Scores: (min: 11, avg: 189.95, max: 500)
#
# Run: 617, exploration: 0.5, score: 98
# Scores: (min: 11, avg: 190.47, max: 500)
#
# Run: 618, exploration: 0.5, score: 246
# Scores: (min: 11, avg: 192.18, max: 500)
#
# Run: 619, exploration: 0.5, score: 270
# Scores: (min: 11, avg: 194.2, max: 500)
#
# Run: 620, exploration: 0.5, score: 272
# Scores: (min: 11, avg: 194.23, max: 500)
#
# Run: 621, exploration: 0.5, score: 150
# Scores: (min: 11, avg: 191.99, max: 500)
#
# Run: 622, exploration: 0.5, score: 93
# Scores: (min: 11, avg: 191, max: 500)
#
# Run: 623, exploration: 0.5, score: 500
# Scores: (min: 11, avg: 191.63, max: 500)
#
# Run: 624, exploration: 0.5, score: 57
# Scores: (min: 11, avg: 189.7, max: 500)
#
# Run: 625, exploration: 0.5, score: 150
# Scores: (min: 11, avg: 189.04, max: 500)
#
# Run: 626, exploration: 0.5, score: 241
# Scores: (min: 18, avg: 191.34, max: 500)
#
# Run: 627, exploration: 0.5, score: 146
# Scores: (min: 18, avg: 188.61, max: 500)
#
# Run: 628, exploration: 0.5, score: 193
# Scores: (min: 18, avg: 189.79, max: 500)
#
# Run: 629, exploration: 0.5, score: 448
# Scores: (min: 18, avg: 191.79, max: 500)
#
# Run: 630, exploration: 0.5, score: 225
# Scores: (min: 18, avg: 189.04, max: 500)
#
# Run: 631, exploration: 0.5, score: 347
# Scores: (min: 18, avg: 191.88, max: 500)
#
# Run: 632, exploration: 0.5, score: 39
# Scores: (min: 18, avg: 188.31, max: 500)
#
# Run: 633, exploration: 0.5, score: 276
# Scores: (min: 18, avg: 189.76, max: 500)
#
# Run: 634, exploration: 0.5, score: 37
# Scores: (min: 18, avg: 189.86, max: 500)
#
# Run: 635, exploration: 0.5, score: 56
# Scores: (min: 18, avg: 185.42, max: 500)
#
# Run: 636, exploration: 0.5, score: 218
# Scores: (min: 18, avg: 186.18, max: 500)
#
# Run: 637, exploration: 0.5, score: 27
# Scores: (min: 18, avg: 185.52, max: 500)
#
# Run: 638, exploration: 0.5, score: 254
# Scores: (min: 18, avg: 186.27, max: 500)
#
# Run: 639, exploration: 0.5, score: 174
# Scores: (min: 18, avg: 187.78, max: 500)
#
# Run: 640, exploration: 0.5, score: 85
# Scores: (min: 18, avg: 187.7, max: 500)
#
# Run: 641, exploration: 0.5, score: 156
# Scores: (min: 18, avg: 188.67, max: 500)
#
# Run: 642, exploration: 0.5, score: 12
# Scores: (min: 12, avg: 183.97, max: 500)
#
# Run: 643, exploration: 0.5, score: 15
# Scores: (min: 12, avg: 180.55, max: 500)
#
# Run: 644, exploration: 0.5, score: 254
# Scores: (min: 12, avg: 181.14, max: 500)
#
# Run: 645, exploration: 0.5, score: 419
# Scores: (min: 12, avg: 184.72, max: 500)
#
# Run: 646, exploration: 0.5, score: 473
# Scores: (min: 12, avg: 188.11, max: 500)
#
# Run: 647, exploration: 0.5, score: 54
# Scores: (min: 12, avg: 186.12, max: 500)
#
# Run: 648, exploration: 0.5, score: 40
# Scores: (min: 12, avg: 185.87, max: 500)
#
# Run: 649, exploration: 0.5, score: 93
# Scores: (min: 12, avg: 186.09, max: 500)
#
# Run: 650, exploration: 0.5, score: 358
# Scores: (min: 12, avg: 188.56, max: 500)
#
# Run: 651, exploration: 0.5, score: 193
# Scores: (min: 12, avg: 189.74, max: 500)
#
# Run: 652, exploration: 0.5, score: 221
# Scores: (min: 12, avg: 190.07, max: 500)
#
# Run: 653, exploration: 0.5, score: 353
# Scores: (min: 12, avg: 192.34, max: 500)
#
# Run: 654, exploration: 0.5, score: 377
# Scores: (min: 12, avg: 192.97, max: 500)
#
# Run: 655, exploration: 0.5, score: 27
# Scores: (min: 12, avg: 192.5, max: 500)
#
# Run: 656, exploration: 0.5, score: 24
# Scores: (min: 12, avg: 190.05, max: 500)
#
# Run: 657, exploration: 0.5, score: 174
# Scores: (min: 12, avg: 190.96, max: 500)
#
# Run: 658, exploration: 0.5, score: 221
# Scores: (min: 12, avg: 189.99, max: 500)
#
# Run: 659, exploration: 0.5, score: 78
# Scores: (min: 12, avg: 189.19, max: 500)
#
# Run: 660, exploration: 0.5, score: 44
# Scores: (min: 12, avg: 187.39, max: 500)
#
# Run: 661, exploration: 0.5, score: 237
# Scores: (min: 12, avg: 187.89, max: 500)
#
# Run: 662, exploration: 0.5, score: 241
# Scores: (min: 12, avg: 189.84, max: 500)
#
# Run: 663, exploration: 0.5, score: 255
# Scores: (min: 12, avg: 190.44, max: 500)
#
# Run: 664, exploration: 0.5, score: 83
# Scores: (min: 12, avg: 190.17, max: 500)
#
# Run: 665, exploration: 0.5, score: 166
# Scores: (min: 12, avg: 188.92, max: 500)
#
# Run: 666, exploration: 0.5, score: 158
# Scores: (min: 12, avg: 188.88, max: 500)
#
# Run: 667, exploration: 0.5, score: 291
# Scores: (min: 12, avg: 190.14, max: 500)
#
# Run: 668, exploration: 0.5, score: 153
# Scores: (min: 12, avg: 189.23, max: 500)
#
# Run: 669, exploration: 0.5, score: 81
# Scores: (min: 12, avg: 186.7, max: 500)
#
# Run: 670, exploration: 0.5, score: 234
# Scores: (min: 12, avg: 188.01, max: 500)
#
# Run: 671, exploration: 0.5, score: 357
# Scores: (min: 12, avg: 191.04, max: 500)
#
# Run: 672, exploration: 0.5, score: 99
# Scores: (min: 12, avg: 190.67, max: 500)
#
# Run: 673, exploration: 0.5, score: 257
# Scores: (min: 12, avg: 192.24, max: 500)
#
# Run: 674, exploration: 0.5, score: 111
# Scores: (min: 12, avg: 193.04, max: 500)
#
# Run: 675, exploration: 0.5, score: 17
# Scores: (min: 12, avg: 191.05, max: 500)
#
# Run: 676, exploration: 0.5, score: 96
# Scores: (min: 12, avg: 189.72, max: 500)
#
# Run: 677, exploration: 0.5, score: 129
# Scores: (min: 12, avg: 189.06, max: 500)
#
# Run: 678, exploration: 0.5, score: 274
# Scores: (min: 12, avg: 191.22, max: 500)
#
# Run: 679, exploration: 0.5, score: 262
# Scores: (min: 12, avg: 193.31, max: 500)
#
# Run: 680, exploration: 0.5, score: 217
# Scores: (min: 12, avg: 193.99, max: 500)
#
# Run: 681, exploration: 0.5, score: 50
# Scores: (min: 12, avg: 192.04, max: 500)
#
# Run: 682, exploration: 0.5, score: 151
# Scores: (min: 12, avg: 191.69, max: 500)
#
# Run: 683, exploration: 0.5, score: 213
# Scores: (min: 12, avg: 188.82, max: 500)
#
# Run: 684, exploration: 0.5, score: 314
# Scores: (min: 12, avg: 191.73, max: 500)
#
# Run: 685, exploration: 0.5, score: 247
# Scores: (min: 12, avg: 194.02, max: 500)
#
# Run: 686, exploration: 0.5, score: 476
# Scores: (min: 12, avg: 194.51, max: 500)
#
# Run: 687, exploration: 0.5, score: 65
# Scores: (min: 12, avg: 194.93, max: 500)
#
# Run: 688, exploration: 0.5, score: 460
# Scores: (min: 12, avg: 197.78, max: 500)
#
# Solved in 588 runs, 688 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-5a34ed7b3a14> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Explain how reinforcement learning concepts apply to the cartpole problem.
#
# The goal of this program "cartpole" is to balance a pole in its center. It does this by moving a cart left or right (the only possible action to take) and attempting to prevent the pole from moving in either direction by more than 15 degrees. The various state values represented are the car position, velocity, pole angle, and the velocity of the tip of the pole.

# %% [markdown]
# ## Analyze how experience replay is applied to the cartpole problem.
#
# This algorithm uses experience replay so that the states experienced by the agent can be remembered and then those experiences sampled. By sampling the algorithm tries to reduce correlation between subsequent actions. The best way to describe the algorithm used is described by Rita Kurban in the book "Deep Q Learning", "Batches of experiences are randomly sampled from memory and are used to train the neural network. Such learning consists of two phases — gaining experience and updating the model. The size of the replay controls the number of experiences that are used for the network update. Memory is an array that stores the agent’s state, reward, and action, as well as whether the action finished the game and the next state." (Surma, 2021) The discount factor determines the importance of future rewards. A factor of 0 will make the agent short-sighted by only considering current rewards, while a factor approaching 1 will make it strive for a long-term high reward.

# %% [markdown]
# ## Analyze how neural networks are used in deep Q-learning
#
# This learning style differs from standard Q-Learning in that a DQN uses a Neural Network. Where Q-Learning updates its Q-values in the Q-table manually, the DQN uses the NN to approximate the values. With standard Q-learning, the Q-value for all possible state-action pairs is manually placed in the Q-table, but with larger amounts of state-actions pairs (think thousands or even millions) this becomes infeasible. Instead, the NN is used to approximate the Q-values in the Q-table, and thus a DQN is created. The neural network makes the Q-Learning algorithm more efficient by estimating the Q values, allowing it to scale and run faster. By adjusting the learning rate for the algorithm and increasing it from 0.001 to 0.01, it almost doubled the number of runs needed to reach the end state.

# %% [markdown]
# ### Reference
#
# Surma, G. (2021, October 13). Cartpole - Introduction to Reinforcement Learning (DQN - Deep Q-Learning). Medium. https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
